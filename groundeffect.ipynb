# %%
from __future__ import print_function
import pandas as pd
import os
import matplotlib.pyplot as plt

import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import torchvision
import torch.utils.data as data
import os
import copy
torch.set_default_tensor_type('torch.DoubleTensor')

import demo_multi
import importlib
importlib.reload(demo_multi)
importlib.reload(plt)
from demo_multi import SplitData, train_validate_test, WeightDataSet, \
    Net, test_regression 

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Fa_data.csv')

# %%
df.columns
# Out:
# Index(['time(s)', ' Fa_x(N)', ' Fa_y(N)', ' Fa_z(N)', ' x(m)', ' y(m)',
#        ' z(m)', ' v_x(m/s)', ' v_y(m/s)', ' v_z(m/s)', ' quaternion_x',
#        ' quaternion_y', ' quaternion_z', ' quaternion_w', ' u_1(RPM)',
#        ' u_2(RPM)', ' u_3(RPM)', ' u_4(RPM)'],
#       dtype='object')

# %%
df[' Fa_x(N)'].plot()

# %%
df[' Fa_y(N)'].plot()

# %%
df[' Fa_z(N)'].plot()

# %%
df[' z(m)'].plot()

# %%
plt.scatter(df[' z(m)'], df[' Fa_z(N)'], alpha=0.1)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class Network(nn.Module):

    def __init__(self):
        super(Network, self).__init__()
        self.fc1 = nn.Linear(12, 25)
        self.fc2 = nn.Linear(25, 30)
        self.fc3 = nn.Linear(30, 15)
        self.fc4 = nn.Linear(15, 3)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)

        return x

def read_weight(filename):
    model_weight = torch.load(filename)
    model = Network()
    model.load_state_dict(model_weight)
    return model

# %%
fa_model = read_weight('Fa_net_12_3_full_Lip16.pth')

# %%
# state is a 12-d vector
# 0: height, z
# 1,2,3: velocity, \dot{x}, \dot{y}, \dot{z}
# 4,5,6,7: quaternion, qx, qy, qz, qw
# 8,9,10,11: control, u1, u2, u3, u4

# input range and constraints
# 0 <= z <= 1.5
# -1 <= \dot{x,y,z} <= 1 
# qx^2 + qy^2 + qz^2 + qw^2 = 1
# 0 <= u1,u2,u3,u4 <= 1

# *******************************************
# Task 1: learn a 4d -> 3d function
# fix qx,qy,qz,qw = 0,0,0,1
# fix u1,u2,u3,u4 = 0.7,0.7,0.7,0.7
# learn the function (z,\dot{x},\dot{y},\dot{z}) -> fa
def fa_output(fa_model, height, velocity, controls=[0.7] * 4):
    state = np.zeros([1, 12])
    state[0, 0] = height
    state[0, 1:4] = velocity
    state[0, 7] = 1.0
    state[0, 8:12] = controls
    state_torch = torch.from_numpy(state)
    #print(state_torch)
    Fa = fa_model(state_torch)
    return Fa

# %%
print(fa_output(fa_model=fa_model, height=0.2, velocity=np.array([0,0,0])))

# *******************************************
# Task 2: learn a 8d -> 3d function
# fix qx,qy,qz,qw = 0,0,0,1
# learn the function (z,\dot{x},\dot{y},\dot{z},u1,u2,u3,u4) -> fa
# Out:
# tensor([[0.2861, 0.0693, 1.3686]], grad_fn=<AddmmBackward>)

# %%
dots = np.zeros((300, 3))
for i in range(300):
    a = fa_output(fa_model=fa_model, height=i/100.0, velocity=np.array([0,0,-1]))
    dots[i] = a[0].detach().numpy()

# %%
plt.plot(dots[:,2])

# %%
plt.plot(dots[:,1])

# %%
plt.plot(dots[:,0])

# %%
np.random.random(4)
# Out:
# array([0.39608319, 0.07712631, 0.61667152, 0.39537138])

# %%
n_rows = 3000
dots = np.zeros((n_rows, 3))
inputs = np.random.random(n_rows * 4).reshape((n_rows, 4))
inputs[:,0] *= 3
inputs[:,1:] = inputs[:,1:] * 2 - 1
for i, x in enumerate(inputs):
    a = fa_output(fa_model=fa_model, height=x[0],
                  velocity=np.array(x[1:]))
    dots[i] = a[0].detach().numpy()

# %%
plt.scatter(inputs[:,0], dots[:,2])

# %%
import seaborn as sns
sns.set(style="darkgrid")
syn_df = pd.DataFrame({
    'Fa_z(N)': dots[:, 2],
    'z(m)': inputs[:, 0]
})
# tips = sns.load_dataset("tips")
# g = sns.jointplot("total_bill", "tip", data=tips,
#                   kind="reg", truncate=False,
#                   xlim=(0, 60), ylim=(0, 12),
#                   color="m", height=7)
g = sns.jointplot("z(m)", "Fa_z(N)", data=syn_df,
                  #kind="scatter",
                  xlim=(-0.2, 3.1), ylim=(-0.5, 2.2),
                  color="b", height=7, joint_kws={'alpha': 0.2})

# %%
'''
d is the dimension of the last layer of network

'''

d = 10

'''
d_out is the dimension of the output variable

'''

d_out = 3


'''
mean0 and var0 is set according to prior knowledge and will not
affect the result a lot in the no shift case.
However, if there is shift and target data is far from source,
base distribution will dominate the result.

'''

mean0 = np.zeros([1, d_out])
var0 = np.eye(d_out)

# %%
class Args:
    pass

use_cuda = False
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}


batch_size = 32
epochs_training = 50
lr = 0.01
lr_yy = 0.01
lr_yx = 0.01
momentum = 0.95
log_interval = 100
lamb = 0.001

args = Args()
args.batch_size = batch_size
args.epochs_training = epochs_training
args.lr = lr
args.lr_yy = lr_yy
args.lr_yx = lr_yx
args.momentum = momentum
args.log_interval = log_interval

# %%
split_data = SplitData(inputs, dots)

# %%
split_data = np.random.permutation(split_data)
train_data = data.Subset(split_data, range(0, int(0.8*len(split_data))))
# 20% test set
test_data = data.Subset(split_data, range(int(0.8*len(split_data)), len(split_data)))

m_train = len(train_data)

# for covariate shift, plug in densities for source data
weight_st = np.ones(m_train)
    
weighted_train = WeightDataSet(train_data, weight_st)
m_test = len(test_data)

# for covariate shift, plug in densities for target data
weight_st = np.ones(m_test)
weighted_test = WeightDataSet(test_data, weight_st)


test_loader = data.DataLoader(weighted_test,
    batch_size=args.batch_size, shuffle=False, **kwargs)

# 10% of training as validation
m_validate = int(0.1*m_train)

validate_loader = data.DataLoader(data.Subset(weighted_train,range(0, m_validate)),
    batch_size=args.batch_size, shuffle=False, **kwargs)

# 10% validation set, note that under shift cases, cannot valiate using training data
train_loader = data.DataLoader(data.Subset(weighted_train, range(m_validate, m_train)),
    batch_size=args.batch_size, shuffle=False, **kwargs)

base_model = Net(4,256, d)
base_model = base_model.to(device)

print("entering training")
model, Myy, Myx, y_pred, y_var, _  = train_validate_test(
    args, args.epochs_training, device, use_cuda, base_model, 
    train_loader, test_loader , validate_loader, lamb)
# Out:
# entering training
# Train Epoch: 1 [0/2160 (0%)]
# gradient yy: 0.8741588542490691
# gradient yx: 0.16584133734414822
# Average loss: 0.3304
#
# Train Epoch: 2 [0/2160 (0%)]
# gradient yy: 0.565931055938044
# gradient yx: 0.09063467529730428
# Average loss: 0.2970
#
# Train Epoch: 3 [0/2160 (0%)]
# gradient yy: 0.4563723211440593
# gradient yx: 0.06886334292771149
# Average loss: 0.2928
#
# Train Epoch: 4 [0/2160 (0%)]
# gradient yy: 0.3903860545098864
# gradient yx: 0.05881689401595179
# Average loss: 0.2891
#
# Train Epoch: 5 [0/2160 (0%)]
# gradient yy: 0.3469028112847004
# gradient yx: 0.05195924625754018
# Average loss: 0.2813
#
# Train Epoch: 6 [0/2160 (0%)]
# gradient yy: 0.3163212862669748
# gradient yx: 0.0473545918122305
# Average loss: 0.2792
#
# Train Epoch: 7 [0/2160 (0%)]
# gradient yy: 0.2934693907355775
# gradient yx: 0.04434105031054068
# Average loss: 0.2759
#
# Train Epoch: 8 [0/2160 (0%)]
# gradient yy: 0.2751515160463671
# gradient yx: 0.04221363148775273
# Average loss: 0.2708
#
# Train Epoch: 9 [0/2160 (0%)]
# gradient yy: 0.2606348068840642
# gradient yx: 0.04046050032178622
# Average loss: 0.2667
#
# Train Epoch: 10 [0/2160 (0%)]
# gradient yy: 0.24854667956719867
# gradient yx: 0.03906281252218642
# Average loss: 0.2629
#
# Train Epoch: 11 [0/2160 (0%)]
# gradient yy: 0.23786188464883357
# gradient yx: 0.037886591270334516
# Average loss: 0.2608
#
# Train Epoch: 12 [0/2160 (0%)]
# gradient yy: 0.22842876110423616
# gradient yx: 0.03701672909328803
# Average loss: 0.2597
#
# Train Epoch: 13 [0/2160 (0%)]
# gradient yy: 0.22013355840846913
# gradient yx: 0.03609824640780626
# Average loss: 0.2588
#
# Train Epoch: 14 [0/2160 (0%)]
# gradient yy: 0.21277065080554072
# gradient yx: 0.03535075142508138
# Average loss: 0.2580
#
# Train Epoch: 15 [0/2160 (0%)]
# gradient yy: 0.20647695095385002
# gradient yx: 0.03459610229996732
# Average loss: 0.2576
#
# Train Epoch: 16 [0/2160 (0%)]
# gradient yy: 0.20049610834042572
# gradient yx: 0.0339560160128358
# Average loss: 0.2572
#
# Train Epoch: 17 [0/2160 (0%)]
# gradient yy: 0.19512966237948892
# gradient yx: 0.03341216006504658
# Average loss: 0.2566
#
# Train Epoch: 18 [0/2160 (0%)]
# gradient yy: 0.19015040238588235
# gradient yx: 0.03298088904436222
# Average loss: 0.2560
#
# Train Epoch: 19 [0/2160 (0%)]
# gradient yy: 0.18549396858715475
# gradient yx: 0.0326336342458245
# Average loss: 0.2555
#
# Train Epoch: 20 [0/2160 (0%)]
# gradient yy: 0.18122444932940357
# gradient yx: 0.03236665484202436
# Average loss: 0.2551
#
# Train Epoch: 21 [0/2160 (0%)]
# gradient yy: 0.1770603479081905
# gradient yx: 0.03233104478146107
# Average loss: 0.2546
#
# Train Epoch: 22 [0/2160 (0%)]
# gradient yy: 0.17334716165896663
# gradient yx: 0.03228302691792672
# Average loss: 0.2542
#
# Train Epoch: 23 [0/2160 (0%)]
# gradient yy: 0.16999046501663284
# gradient yx: 0.032643439051194545
# Average loss: 0.2538
#
# Train Epoch: 24 [0/2160 (0%)]
# gradient yy: 0.16675554554868324
# gradient yx: 0.03359271315206087
# Average loss: 0.2536
#
# Train Epoch: 25 [0/2160 (0%)]
# gradient yy: 0.16384271051761462
# gradient yx: 0.035649492428186776
# Average loss: 0.2537
#
# Train Epoch: 26 [0/2160 (0%)]
# gradient yy: 0.1608363550218235
# gradient yx: 0.039357173806137985
# Average loss: 0.2539
#
# Train Epoch: 27 [0/2160 (0%)]
# gradient yy: 0.15769117016143752
# gradient yx: 0.04564275686923145
# Average loss: 0.2523
#
# Train Epoch: 28 [0/2160 (0%)]
# gradient yy: 0.15586590551644064
# gradient yx: 0.05686349477808869
# Average loss: 0.2502
#
# Train Epoch: 29 [0/2160 (0%)]
# gradient yy: 0.15332090420576663
# gradient yx: 0.072891541295668
# Average loss: 0.2479
#
# Train Epoch: 30 [0/2160 (0%)]
# gradient yy: 0.1505159349315204
# gradient yx: 0.09663216810594802
# Average loss: 0.2466
#
# Train Epoch: 31 [0/2160 (0%)]
# gradient yy: 0.14954380068240777
# gradient yx: 0.1202479591752062
# Average loss: 0.2449
#
# Train Epoch: 32 [0/2160 (0%)]
# gradient yy: 0.1483314113783887
# gradient yx: 0.13582699668233367
# Average loss: 0.2309
#
# Train Epoch: 33 [0/2160 (0%)]
# gradient yy: 0.14718073404880028
# gradient yx: 0.14491826740197275
# Average loss: 0.2224
#
# Train Epoch: 34 [0/2160 (0%)]
# gradient yy: 0.1502684736292474
# gradient yx: 0.13593704025437778
# Average loss: 0.2201
#
# Train Epoch: 35 [0/2160 (0%)]
# gradient yy: 0.15256695401595538
# gradient yx: 0.12435419039531852
# Average loss: 0.2107
#
# Train Epoch: 36 [0/2160 (0%)]
# gradient yy: 0.15328615298981355
# gradient yx: 0.11398680689198801
# Average loss: 0.1941
#
# Train Epoch: 37 [0/2160 (0%)]
# gradient yy: 0.15385883529169922
# gradient yx: 0.10714094398070854
# Average loss: 0.1900
#
# Train Epoch: 38 [0/2160 (0%)]
# gradient yy: 0.15634954515294303
# gradient yx: 0.11008870862240636
# Average loss: 0.1853
#
# Train Epoch: 39 [0/2160 (0%)]
# gradient yy: 0.1555734611314905
# gradient yx: 0.10934797519109037
# Average loss: 0.1785
#
# Train Epoch: 40 [0/2160 (0%)]
# gradient yy: 0.1553753023625306
# gradient yx: 0.11894894726385499
# Average loss: 0.1690
#
# Train Epoch: 41 [0/2160 (0%)]
# gradient yy: 0.15596788094600458
# gradient yx: 0.1277164215614905
# Average loss: 0.1573
#
# Train Epoch: 42 [0/2160 (0%)]
# gradient yy: 0.1567746867039607
# gradient yx: 0.13017789554738224
# Average loss: 0.1497
#
# Train Epoch: 43 [0/2160 (0%)]
# gradient yy: 0.15712327417291372
# gradient yx: 0.1258008113762958
# Average loss: 0.1383
#
# Train Epoch: 44 [0/2160 (0%)]
# gradient yy: 0.15802061178095067
# gradient yx: 0.12013994950975913
# Average loss: 0.1250
#
# Train Epoch: 45 [0/2160 (0%)]
# gradient yy: 0.16248044270020567
# gradient yx: 0.09979952966460212
# Average loss: 0.1153
#
# Train Epoch: 46 [0/2160 (0%)]
# gradient yy: 0.16264329553911946
# gradient yx: 0.09394480445721655
# Average loss: 0.1138
#
# Train Epoch: 47 [0/2160 (0%)]
# gradient yy: 0.16391364751506637
# gradient yx: 0.08229224462647845
# Average loss: 0.1108
#
# Train Epoch: 48 [0/2160 (0%)]
# gradient yy: 0.1661776647637223
# gradient yx: 0.07304168930067888
# Average loss: 0.1098
#
# Train Epoch: 49 [0/2160 (0%)]
# gradient yy: 0.1666206965762181
# gradient yx: 0.07098400865160355
# Average loss: 0.1087
#
# Train Epoch: 50 [0/2160 (0%)]
# gradient yy: 0.16380232119838845
# gradient yx: 0.07108343765706183
# Average loss: 0.1008
#
#
# Testing on test set
# Average loss: 0.0956

# %%
a = test_data[1:3][:,0]

#a.astype(float)
np.array(list(a))
# Out:
# array([[ 2.05485628,  0.54171543,  0.12885168, -0.27888759],
#        [ 0.22139728,  0.82199685,  0.21668541,  0.68725924]])

# %%
test_data_t = torch.Tensor(list(test_data[:][:,0]))
test_y_t = torch.Tensor(list(test_data[:][:,1]))
test_preds = model.forward(test_data_t).detach()

# %%
np.sqrt(((test_y_t - y_pred) ** 2).mean())
# Out:
# tensor(0.0956)

# %%
len(test_loader.dataset)
# Out:
# 600

# %%
plt.scatter(test_data_t[:,0], test_y_t[:,2])

# %%
test_z = np.array(list(test_data[:][:,0]))[:,0]
test_zdot = test_preds[:,-1]
plt.scatter(test_z, test_zdot)

# %%
direct_test_preds, direct_test_var, direct_test_loss = demo_multi.test_regression(args, model, Myy, Myx, device, test_loader, mean0, var0)

plt.scatter(test_z, direct_test_preds[:,-1])
# Out:
# Average loss: 0.0956

# %%
import seaborn as sns
sns.set(style="darkgrid")
syn_df = pd.DataFrame({
    'Fa_z(N)': direct_test_preds[:, -1],
    'z(m)': test_z
})
g = sns.scatterplot("z(m)", "Fa_z(N)", data=syn_df,
                    #xlim=(-0.2, 3.1), ylim=(-0.5, 2.2),
                    color="b",
                    #height=7,
                    #joint_kws={'alpha': 0.2}
                    alpha=0.2,
                   )

plt.ylim((-0.5, 2.2))
plt.title('Robust Regression (RMSE: 0.096)')
# Out:
# Text(0.5, 1.0, 'Robust Regression (RMSE: 0.096)')

# %%
# test_y_t[:,2]

# %%
import seaborn as sns
sns.set(style="darkgrid")
syn_df = pd.DataFrame({
    'Fa_z error(N)': direct_test_preds[:, -1] - test_y_t[:,2].detach().numpy(),
    'z(m)': test_z
})
g = sns.scatterplot("z(m)", "Fa_z error(N)", data=syn_df,
                    #xlim=(-0.2, 3.1), ylim=(-0.5, 2.2),
                    color="b",
                    #height=7,
                    #joint_kws={'alpha': 0.2}
                    alpha=0.2,
                   )

plt.title('Robust Regression error (RMSE: 0.096)')
# Out:
# Text(0.5, 1.0, 'Robust Regression error (RMSE: 0.096)')

# %%
np.quantile(direct_test_preds[:, -1] - test_y_t[:,2].detach().numpy(), 0.05)
# Out:
# -0.3228302277542752

# %%
plt.scatter(test_z, y_pred[:, 2])

# %%
test_zdot_gt = np.array(list(test_data[:][:,1]))[:,-1]

plt.scatter(test_z, test_zdot_gt)

# %%
print(__doc__)

# Author: Vincent Dubourg <vincent.dubourg@gmail.com>
#         Jake Vanderplas <vanderplas@astro.washington.edu>
#         Jan Hendrik Metzen <jhm@informatik.uni-bremen.de>s
# License: BSD 3 clause

import numpy as np
from matplotlib import pyplot as plt

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C

np.random.seed(1)
# Out:
# mean0 and var0 is set according to prior knowledge and will not
# affect the result a lot in the no shift case.
# However, if there is shift and target data is far from source,
# base distribution will dominate the result.

# %%
X = inputs.copy()[:1000]
x = np.zeros(X.shape)
x[:,0] = np.linspace(min(X[:,0]),max(X[:,0]), X.shape[0])
Y = dots.copy()[:1000]
dY = (0.5 + 1.0 * np.random.random(Y.shape)) * 0.1
noise = np.random.normal(0, dY)
Y += noise
print(X.shape, Y.shape, x.shape, dY.shape)
# Out:
# (1000, 4) (1000, 3) (1000, 4) (1000, 3)

# %%
n = X.shape[0]
X_train = X[:int(0.8 * n)]
X_test = X[int(0.8 * n):]
Y_train = Y[:int(0.8 * n)]
Y_test = Y[int(0.8 * n):]
dy_train = dY[:int(0.8 * n)]
dy_test = dY[int(0.8 * n):]
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (800, 4) (200, 4) (800, 3) (200, 3)

# %%
# Instantiate a Gaussian Process model
kernel = RBF(0.1)
gp = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp.fit(X_train, Y_train)

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred, sigma = gp.predict(X_test, return_std=True)

# %%
np.sqrt(((Y_test - y_pred) ** 2).mean())
# Out:
# 0.12272914794106218

# %%
plt.scatter(X_test[:,0], y_pred[:,2])

# %%
import seaborn as sns
sns.set(style="darkgrid")
syn_df = pd.DataFrame({
    'Fa_z(N)': y_pred[:,2],
    'z(m)': X_test[:, 0]
})
g = sns.scatterplot("z(m)", "Fa_z(N)", data=syn_df,
                    #xlim=(-0.2, 3.1), ylim=(-0.5, 2.2),
                    color="b",
                    #height=7,
                    #joint_kws={'alpha': 0.2}
                    alpha=0.8,
                   )

plt.ylim((-0.5, 2.2))
plt.title('Gaussian Process (RMSE: 0.120)')
# Out:
# Text(0.5, 1.0, 'Gaussian Process (RMSE: 0.120)')

# %%
np.quantile(y_pred[:,2] - Y_test[:,2], 0.95)
# Out:
# 0.2154571357606839

# %%
plt.scatter(X_train[:,0], Y_train[:,2])

# %%
# Instantiate a Gaussian Process model
gp_0 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)
gp_1 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)
gp_2 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp_0.fit(X_train, Y_train[:,0])
gp_1.fit(X_train, Y_train[:,1])
gp_2.fit(X_train, Y_train[:,2])

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred_0, sigma = gp_0.predict(X_test, return_std=True)
y_pred_1, sigma = gp_1.predict(X_test, return_std=True)
y_pred_2, sigma = gp_2.predict(X_test, return_std=True)

# %%
np.sqrt(((Y_test - np.vstack((y_pred_0, y_pred_1, y_pred_2)).T) ** 2).mean())
# Out:
# 0.11978009622722825

# %%
plt.scatter(X_test[:,0], y_pred[:,-1])

plt.xlabel('z(m)')
plt.ylabel('Fa_z(N)')
plt.title('3D, Synthetic, GP, Test predictions')
# Out:
# Text(0.5, 1.0, '3D, Synthetic, GP, Test predictions')

# %%
plt.scatter(X_train[:,0], Y_train[:,2])
plt.xlabel('z(m)')
plt.ylabel('Fa_z(N)')
plt.title('3D, Synthetic, GP, Training data')
# Out:
# Text(0.5, 1.0, '3D, Synthetic, GP, Training data')

# %%
n_rows = 3000
d_in = 8
d_out = 3
dots = np.zeros((n_rows, 3))
inputs = np.random.random(n_rows * d_in).reshape((n_rows, d_in))
inputs[:,0] *= 3
inputs[:,1:] = inputs[:,1:] * 2 - 1
for i, x in enumerate(inputs):
    a = fa_output(fa_model=fa_model, height=x[0],
                  velocity=x[1:4], controls=x[4:])
    dots[i] = a[0].detach().numpy()

# %%
class Args:
    pass

use_cuda = False
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

batch_size = 32
epochs_training = 50
lr = 0.0005
lr_yx = lr
lr_yy = lr
momentum = 0.5
log_interval = 100
lamb = 0.001

args = Args()
args.batch_size = batch_size
args.epochs_training = epochs_training
args.lr = lr
args.lr_yy = lr_yy
args.lr_yx = lr_yx
args.momentum = momentum
args.log_interval = log_interval
split_data = SplitData(inputs, dots)

# %%
split_data = np.random.permutation(split_data)
train_data = data.Subset(split_data, range(0, int(0.8*len(split_data))))
# 20% test set
test_data = data.Subset(split_data, range(int(0.8*len(split_data)), len(split_data)))

m_train = len(train_data)

# for covariate shift, plug in densities for source data
weight_st = np.ones(m_train)
    
weighted_train = WeightDataSet(train_data, weight_st)
m_test = len(test_data)

# for covariate shift, plug in densities for target data
weight_st = np.ones(m_test)
weighted_test = WeightDataSet(test_data, weight_st)


test_loader = data.DataLoader(weighted_test,
    batch_size=args.batch_size, shuffle=False, **kwargs)

# 10% of training as validation
m_validate = int(0.1*m_train)

validate_loader = data.DataLoader(data.Subset(weighted_train,range(0, m_validate)),
    batch_size=args.batch_size, shuffle=False, **kwargs)

# 10% validation set, note that under shift cases, cannot valiate using training data
train_loader = data.DataLoader(data.Subset(weighted_train, range(m_validate, m_train)),
    batch_size=args.batch_size, shuffle=False, **kwargs)

base_model = Net(d_in, 256, d)
base_model = base_model.to(device)

print("entering training")
model, Myy, Myx, y_pred, y_var, _  = train_validate_test(
    args, args.epochs_training, device, use_cuda, base_model, 
    train_loader, test_loader , validate_loader, lamb)
# Out:
# entering training
# Train Epoch: 1 [0/2160 (0%)]
# gradient yy: 1.1488098855329023
# gradient yx: 0.849774919146858
# Average loss: 0.6320
#
# Train Epoch: 2 [0/2160 (0%)]
# gradient yy: 1.085662497575082
# gradient yx: 0.7886375750207847
# Average loss: 0.6055
#
# Train Epoch: 3 [0/2160 (0%)]
# gradient yy: 1.0320382168008686
# gradient yx: 0.7336918870467465
# Average loss: 0.5819
#
# Train Epoch: 4 [0/2160 (0%)]
# gradient yy: 0.9850267785414237
# gradient yx: 0.6834163951899107
# Average loss: 0.5609
#
# Train Epoch: 5 [0/2160 (0%)]
# gradient yy: 0.9434967690256512
# gradient yx: 0.6373636536193811
# Average loss: 0.5422
#
# Train Epoch: 6 [0/2160 (0%)]
# gradient yy: 0.9067765465070499
# gradient yx: 0.5952531597442482
# Average loss: 0.5255
#
# Train Epoch: 7 [0/2160 (0%)]
# gradient yy: 0.8743293761283695
# gradient yx: 0.5568273296381188
# Average loss: 0.5106
#
# Train Epoch: 8 [0/2160 (0%)]
# gradient yy: 0.8456867450664505
# gradient yx: 0.5218414172293491
# Average loss: 0.4974
#
# Train Epoch: 9 [0/2160 (0%)]
# gradient yy: 0.8203985734430288
# gradient yx: 0.4900467735650858
# Average loss: 0.4857
#
# Train Epoch: 10 [0/2160 (0%)]
# gradient yy: 0.7980213500810732
# gradient yx: 0.4611879177813712
# Average loss: 0.4753
#
# Train Epoch: 11 [0/2160 (0%)]
# gradient yy: 0.7781462996758122
# gradient yx: 0.43501771750503015
# Average loss: 0.4660
#
# Train Epoch: 12 [0/2160 (0%)]
# gradient yy: 0.7603972668320428
# gradient yx: 0.41129624052628583
# Average loss: 0.4577
#
# Train Epoch: 13 [0/2160 (0%)]
# gradient yy: 0.7444523940590331
# gradient yx: 0.38980228140395295
# Average loss: 0.4503
#
# Train Epoch: 14 [0/2160 (0%)]
# gradient yy: 0.730015639846945
# gradient yx: 0.37031799445553015
# Average loss: 0.4436
#
# Train Epoch: 15 [0/2160 (0%)]
# gradient yy: 0.7168542135089757
# gradient yx: 0.3526532271006788
# Average loss: 0.4375
#
# Train Epoch: 16 [0/2160 (0%)]
# gradient yy: 0.7047410420343828
# gradient yx: 0.3366119344266672
# Average loss: 0.4320
#
# Train Epoch: 17 [0/2160 (0%)]
# gradient yy: 0.6935159244094763
# gradient yx: 0.3220353975169638
# Average loss: 0.4270
#
# Train Epoch: 18 [0/2160 (0%)]
# gradient yy: 0.6830312023532641
# gradient yx: 0.30876763542731384
# Average loss: 0.4223
#
# Train Epoch: 19 [0/2160 (0%)]
# gradient yy: 0.6731865543294446
# gradient yx: 0.2966821218766788
# Average loss: 0.4179
#
# Train Epoch: 20 [0/2160 (0%)]
# gradient yy: 0.6638940879800795
# gradient yx: 0.2856588521950271
# Average loss: 0.4138
#
# Train Epoch: 21 [0/2160 (0%)]
# gradient yy: 0.655094189908472
# gradient yx: 0.2755969086550947
# Average loss: 0.4100
#
# Train Epoch: 22 [0/2160 (0%)]
# gradient yy: 0.6466647025122014
# gradient yx: 0.2663507724538365
# Average loss: 0.4064
#
# Train Epoch: 23 [0/2160 (0%)]
# gradient yy: 0.6385520665282555
# gradient yx: 0.2578366256654375
# Average loss: 0.4029
#
# Train Epoch: 24 [0/2160 (0%)]
# gradient yy: 0.6307362907795767
# gradient yx: 0.24999664392873644
# Average loss: 0.3994
#
# Train Epoch: 25 [0/2160 (0%)]
# gradient yy: 0.6231895608073337
# gradient yx: 0.24277046340418137
# Average loss: 0.3960
#
# Train Epoch: 26 [0/2160 (0%)]
# gradient yy: 0.6159136362399441
# gradient yx: 0.23612046233174078
# Average loss: 0.3927
#
# Train Epoch: 27 [0/2160 (0%)]
# gradient yy: 0.608933021748828
# gradient yx: 0.23002394999202677
# Average loss: 0.3896
#
# Train Epoch: 28 [0/2160 (0%)]
# gradient yy: 0.602268564127308
# gradient yx: 0.22443986500281932
# Average loss: 0.3866
#
# Train Epoch: 29 [0/2160 (0%)]
# gradient yy: 0.5956666696353498
# gradient yx: 0.2191349076297052
# Average loss: 0.3836
#
# Train Epoch: 30 [0/2160 (0%)]
# gradient yy: 0.5891844541775805
# gradient yx: 0.21416435109252407
# Average loss: 0.3805
#
# Train Epoch: 31 [0/2160 (0%)]
# gradient yy: 0.5828839092380079
# gradient yx: 0.20956586114988218
# Average loss: 0.3774
#
# Train Epoch: 32 [0/2160 (0%)]
# gradient yy: 0.5768594937705736
# gradient yx: 0.20537542093113897
# Average loss: 0.3745
#
# Train Epoch: 33 [0/2160 (0%)]
# gradient yy: 0.5708425710039858
# gradient yx: 0.20131576368799636
# Average loss: 0.3714
#
# Train Epoch: 34 [0/2160 (0%)]
# gradient yy: 0.5649297146975282
# gradient yx: 0.19751229785287436
# Average loss: 0.3684
#
# Train Epoch: 35 [0/2160 (0%)]
# gradient yy: 0.5592524426576708
# gradient yx: 0.1940418261165049
# Average loss: 0.3654
#
# Train Epoch: 36 [0/2160 (0%)]
# gradient yy: 0.5537105452613469
# gradient yx: 0.19079821034733785
# Average loss: 0.3624
#
# Train Epoch: 37 [0/2160 (0%)]
# gradient yy: 0.5483467610290886
# gradient yx: 0.18779578149769008
# Average loss: 0.3596
#
# Train Epoch: 38 [0/2160 (0%)]
# gradient yy: 0.543088712860339
# gradient yx: 0.18494016469133795
# Average loss: 0.3567
#
# Train Epoch: 39 [0/2160 (0%)]
# gradient yy: 0.537881703093889
# gradient yx: 0.1821849600192458
# Average loss: 0.3538
#
# Train Epoch: 40 [0/2160 (0%)]
# gradient yy: 0.5327897164463578
# gradient yx: 0.17959762912997593
# Average loss: 0.3509
#
# Train Epoch: 41 [0/2160 (0%)]
# gradient yy: 0.5279472891682184
# gradient yx: 0.17727966700325376
# Average loss: 0.3485
#
# Train Epoch: 42 [0/2160 (0%)]
# gradient yy: 0.5231623361963577
# gradient yx: 0.17493249581693154
# Average loss: 0.3459
#
# Train Epoch: 43 [0/2160 (0%)]
# gradient yy: 0.5185502440469548
# gradient yx: 0.17277058757677197
# Average loss: 0.3439
#
# Train Epoch: 44 [0/2160 (0%)]
# gradient yy: 0.5140514401516935
# gradient yx: 0.1706823983068111
# Average loss: 0.3418
#
# Train Epoch: 45 [0/2160 (0%)]
# gradient yy: 0.5096940398571814
# gradient yx: 0.16870939412459737
# Average loss: 0.3395
#
# Train Epoch: 46 [0/2160 (0%)]
# gradient yy: 0.5052932187171912
# gradient yx: 0.16666429470950553
# Average loss: 0.3372
#
# Train Epoch: 47 [0/2160 (0%)]
# gradient yy: 0.501146889732327
# gradient yx: 0.1649165411572725
# Average loss: 0.3352
#
# Train Epoch: 48 [0/2160 (0%)]
# gradient yy: 0.4971236423907343
# gradient yx: 0.16321593227256884
# Average loss: 0.3333
#
# Train Epoch: 49 [0/2160 (0%)]
# gradient yy: 0.4931794851783085
# gradient yx: 0.16152769543093343
# Average loss: 0.3314
#
# Train Epoch: 50 [0/2160 (0%)]
# gradient yy: 0.4893688575839818
# gradient yx: 0.15994969743705528
# Average loss: 0.3295
#
#
# Testing on test set
# Average loss: 0.3378

# %%
test_data_t = torch.Tensor(list(test_data[:][:,0]))
test_y_t = torch.Tensor(list(test_data[:][:,1]))
test_preds = model.forward(test_data_t).detach()
plt.scatter(test_data_t[:,0], test_y_t[:,2])

# %%
n = len(dots)
np.sqrt(((dots[int(len(dots) * 0.8):] - y_pred) ** 2).mean())
# Out:
# 0.5622846827535308

# %%
test_data_t = torch.Tensor(list(test_data[:][:,0]))
test_y_t = torch.Tensor(list(test_data[:][:,1]))
test_preds = model.forward(test_data_t).detach()
np.sqrt(((test_y_t - y_pred) ** 2).mean())
# Out:
# tensor(0.0781)

# %%
y_pred_rr = y_pred
direct_test_preds, direct_test_var, direct_test_loss = demo_multi.test_regression(args, model, Myy, Myx, device, test_loader, mean0, var0)

import seaborn as sns
sns.set(style="darkgrid")
syn_df = pd.DataFrame({
    'Fa_z(N)': direct_test_preds[:, -1],
    'z(m)': test_z
})
g = sns.scatterplot("z(m)", "Fa_z(N)", data=syn_df,
                    #xlim=(-0.2, 3.1), ylim=(-0.5, 2.2),
                    color="b",
                    #height=7,
                    #joint_kws={'alpha': 0.2}
                    alpha=0.2,
                   )

#plt.ylim((-0.5, 2.2))
plt.title('Robust Regression (RMSE: 0.096)')
# Out:
# Average loss: 0.0781
# Text(0.5, 1.0, 'Robust Regression (RMSE: 0.096)')

# %%
X = inputs.copy()[:1000]
x = np.zeros(X.shape)
x[:,0] = np.linspace(min(X[:,0]),max(X[:,0]), X.shape[0])
Y = dots.copy()[:1000]
dY = (0.5 + 1.0 * np.random.random(Y.shape)) * 0.1
noise = np.random.normal(0, dY)
Y += noise
print(X.shape, Y.shape, x.shape, dY.shape)
# Out:
# (1000, 8) (1000, 3) (1000, 8) (1000, 3)

# %%
n = X.shape[0]
X_train = X[:int(0.8 * n)]
X_test = X[int(0.8 * n):]
Y_train = Y[:int(0.8 * n)]
Y_test = Y[int(0.8 * n):]
dy_train = dY[:int(0.8 * n)]
dy_test = dY[int(0.8 * n):]
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (800, 8) (200, 8) (800, 3) (200, 3)

# %%
# Instantiate a Gaussian Process model
kernel = RBF(0.01)
gp = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp.fit(X_train, Y_train)

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred, sigma = gp.predict(X_test, return_std=True)

# %%
np.sqrt(((Y_test - y_pred) ** 2).mean())
# Out:
# 0.14223583163742826

# %%
# Instantiate a Gaussian Process model
gp_0 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)
gp_1 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)
gp_2 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp_0.fit(X_train, Y_train[:,0])
gp_1.fit(X_train, Y_train[:,1])
gp_2.fit(X_train, Y_train[:,2])

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred_0, sigma = gp_0.predict(X_test, return_std=True)
y_pred_1, sigma = gp_1.predict(X_test, return_std=True)
y_pred_2, sigma = gp_2.predict(X_test, return_std=True)

# %%
np.sqrt(((Y_test - np.vstack((y_pred_0, y_pred_1, y_pred_2)).T) ** 2).mean())
# Out:
# 0.13946106913603606

# %%
plt.scatter(X_test[:,0], y_pred[:,-1])

plt.xlabel('z(m)')
plt.ylabel('Fa_z(N)')
plt.title('3D, Synthetic, GP, Test predictions')
# Out:
# Text(0.5, 1.0, '3D, Synthetic, GP, Test predictions')

# %%
plt.scatter(X_train[:,0], Y_train[:,2])
plt.xlabel('z(m)')
plt.ylabel('Fa_z(N)')
plt.title('3D, Synthetic, GP, Training data')
# Out:
# Text(0.5, 1.0, '3D, Synthetic, GP, Training data')
