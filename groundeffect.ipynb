# %%
from __future__ import print_function
import pandas as pd
import os
import matplotlib.pyplot as plt

import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import torchvision
import torch.utils.data as data
import os
import copy
torch.set_default_tensor_type('torch.DoubleTensor')

import demo_multi
import importlib
importlib.reload(demo_multi)
importlib.reload(plt)
from demo_multi import SplitData, train_validate_test, WeightDataSet, \
    Net, test_regression 

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Fa_data.csv')

# %%
df.columns
# Out:
# Index(['time(s)', ' Fa_x(N)', ' Fa_y(N)', ' Fa_z(N)', ' x(m)', ' y(m)',
#        ' z(m)', ' v_x(m/s)', ' v_y(m/s)', ' v_z(m/s)', ' quaternion_x',
#        ' quaternion_y', ' quaternion_z', ' quaternion_w', ' u_1(RPM)',
#        ' u_2(RPM)', ' u_3(RPM)', ' u_4(RPM)'],
#       dtype='object')

# %%
df[' Fa_x(N)'].plot()

# %%
df[' Fa_y(N)'].plot()

# %%
df[' Fa_z(N)'].plot()

# %%
df[' z(m)'].plot()

# %%
plt.scatter(df[' z(m)'], df[' Fa_z(N)'], alpha=0.1)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class Network(nn.Module):

    def __init__(self):
        super(Network, self).__init__()
        self.fc1 = nn.Linear(12, 25)
        self.fc2 = nn.Linear(25, 30)
        self.fc3 = nn.Linear(30, 15)
        self.fc4 = nn.Linear(15, 3)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)

        return x

def read_weight(filename):
    model_weight = torch.load(filename)
    model = Network()
    model.load_state_dict(model_weight)
    return model

# %%
fa_model = read_weight('Fa_net_12_3_full_Lip16.pth')

# %%
# state is a 12-d vector
# 0: height, z
# 1,2,3: velocity, \dot{x}, \dot{y}, \dot{z}
# 4,5,6,7: quaternion, qx, qy, qz, qw
# 8,9,10,11: control, u1, u2, u3, u4

# input range and constraints
# 0 <= z <= 1.5
# -1 <= \dot{x,y,z} <= 1 
# qx^2 + qy^2 + qz^2 + qw^2 = 1
# 0 <= u1,u2,u3,u4 <= 1

# *******************************************
# Task 1: learn a 4d -> 3d function
# fix qx,qy,qz,qw = 0,0,0,1
# fix u1,u2,u3,u4 = 0.7,0.7,0.7,0.7
# learn the function (z,\dot{x},\dot{y},\dot{z}) -> fa
def fa_output(fa_model, height, velocity, controls=[0.7] * 4):
    state = np.zeros([1, 12])
    state[0, 0] = height
    state[0, 1:4] = velocity
    state[0, 7] = 1.0
    state[0, 8:12] = controls
    state_torch = torch.from_numpy(state)
    #print(state_torch)
    Fa = fa_model(state_torch)
    return Fa

# %%
print(fa_output(fa_model=fa_model, height=0.2, velocity=np.array([0,0,0])))

# *******************************************
# Task 2: learn a 8d -> 3d function
# fix qx,qy,qz,qw = 0,0,0,1
# learn the function (z,\dot{x},\dot{y},\dot{z},u1,u2,u3,u4) -> fa
# Out:
# tensor([[0.2861, 0.0693, 1.3686]], grad_fn=<AddmmBackward>)

# %%
dots = np.zeros((300, 3))
for i in range(300):
    a = fa_output(fa_model=fa_model, height=i/100.0, velocity=np.array([0,0,-1]))
    dots[i] = a[0].detach().numpy()

# %%
plt.plot(dots[:,2])

# %%
plt.plot(dots[:,1])

# %%
plt.plot(dots[:,0])

# %%
np.random.random(4)
# Out:
# array([0.7609592 , 0.61525881, 0.9435133 , 0.50579592])

# %%
n_rows = 10000
dots = np.zeros((n_rows, 3))
inputs = np.random.random(n_rows * 4).reshape((n_rows, 4))
inputs[:,0] *= 3
inputs[:,1:] = inputs[:,1:] * 2 - 1
for i, x in enumerate(inputs):
    a = fa_output(fa_model=fa_model, height=x[0],
                  velocity=np.array(x[1:]))
    dots[i] = a[0].detach().numpy()

# %%
plt.scatter(inputs[:,0], dots[:,2])

# %%
import seaborn as sns
sns.set(style="darkgrid")
syn_df = pd.DataFrame({
    'Fa_z(N)': dots[:, 2],
    'z(m)': inputs[:, 0]
})
# tips = sns.load_dataset("tips")
# g = sns.jointplot("total_bill", "tip", data=tips,
#                   kind="reg", truncate=False,
#                   xlim=(0, 60), ylim=(0, 12),
#                   color="m", height=7)
g = sns.jointplot("z(m)", "Fa_z(N)", data=syn_df,
                  #kind="scatter",
                  xlim=(-0.2, 3.1), ylim=(-0.5, 2.2),
                  color="b", height=7, joint_kws={'alpha': 0.2})

# %%
'''
d is the dimension of the last layer of network

'''

d = 10

'''
d_out is the dimension of the output variable

'''

d_out = 3


'''
mean0 and var0 is set according to prior knowledge and will not
affect the result a lot in the no shift case.
However, if there is shift and target data is far from source,
base distribution will dominate the result.

'''

mean0 = np.zeros([1, d_out])
var0 = np.eye(d_out)

# %%
class Args:
    pass

use_cuda = False
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}


batch_size = 32
epochs_training = 50
lr = 0.0005
momentum = 0.5
log_interval = 100
lamb = 0.001

args = Args()
args.batch_size = batch_size
args.epochs_training = epochs_training
args.lr = lr
args.momentum = momentum
args.log_interval = log_interval

# %%
split_data = SplitData(inputs, dots)

# %%
split_data = np.random.permutation(split_data)
train_data = data.Subset(split_data, range(0, int(0.8*len(split_data))))
# 20% test set
test_data = data.Subset(split_data, range(int(0.8*len(split_data)), len(split_data)))

m_train = len(train_data)

# for covariate shift, plug in densities for source data
weight_st = np.ones(m_train)
    
weighted_train = WeightDataSet(train_data, weight_st)
m_test = len(test_data)

# for covariate shift, plug in densities for target data
weight_st = np.ones(m_test)
weighted_test = WeightDataSet(test_data, weight_st)


test_loader = data.DataLoader(weighted_test,
    batch_size=args.batch_size, shuffle=False, **kwargs)

# 10% of training as validation
m_validate = int(0.1*m_train)

validate_loader = data.DataLoader(data.Subset(weighted_train,range(0, m_validate)),
    batch_size=args.batch_size, shuffle=False, **kwargs)

# 10% validation set, note that under shift cases, cannot valiate using training data
train_loader = data.DataLoader(data.Subset(weighted_train, range(m_validate, m_train)),
    batch_size=args.batch_size, shuffle=False, **kwargs)

base_model = Net(4,256, d)
base_model = base_model.to(device)

print("entering training")
model, Myy, Myx, y_pred, y_var, _  = train_validate_test(
    args, args.epochs_training, device, use_cuda, base_model, 
    train_loader, test_loader , validate_loader, lamb)
# Out:
# entering training
# Train Epoch: 1 [0/7200 (0%)]
# Train Epoch: 1 [3200/7200 (44%)]
# Train Epoch: 1 [6400/7200 (89%)]
# gradient yy: 1.145913577100575
# gradient yx: 0.3141222291611663
# Average loss: 0.5601
#
# Train Epoch: 2 [0/7200 (0%)]
# Train Epoch: 2 [3200/7200 (44%)]
# Train Epoch: 2 [6400/7200 (89%)]
# gradient yy: 0.9876900291982986
# gradient yx: 0.17943535473172428
# Average loss: 0.5489
#
# Train Epoch: 3 [0/7200 (0%)]
# Train Epoch: 3 [3200/7200 (44%)]
# Train Epoch: 3 [6400/7200 (89%)]
# gradient yy: 0.8821533787156438
# gradient yx: 0.1534268032962314
# Average loss: 0.5409
#
# Train Epoch: 4 [0/7200 (0%)]
# Train Epoch: 4 [3200/7200 (44%)]
# Train Epoch: 4 [6400/7200 (89%)]
# gradient yy: 0.8049375677490027
# gradient yx: 0.1354780298344641
# Average loss: 0.5346
#
# Train Epoch: 5 [0/7200 (0%)]
# Train Epoch: 5 [3200/7200 (44%)]
# Train Epoch: 5 [6400/7200 (89%)]
# gradient yy: 0.7451748155987656
# gradient yx: 0.12229924866502104
# Average loss: 0.5293
#
# Train Epoch: 6 [0/7200 (0%)]
# Train Epoch: 6 [3200/7200 (44%)]
# Train Epoch: 6 [6400/7200 (89%)]
# gradient yy: 0.697099397485859
# gradient yx: 0.11216614882005281
# Average loss: 0.5243
#
# Train Epoch: 7 [0/7200 (0%)]
# Train Epoch: 7 [3200/7200 (44%)]
# Train Epoch: 7 [6400/7200 (89%)]
# gradient yy: 0.6573153079881427
# gradient yx: 0.10411839475902794
# Average loss: 0.5193
#
# Train Epoch: 8 [0/7200 (0%)]
# Train Epoch: 8 [3200/7200 (44%)]
# Train Epoch: 8 [6400/7200 (89%)]
# gradient yy: 0.6236592307042491
# gradient yx: 0.09758533175274695
# Average loss: 0.5145
#
# Train Epoch: 9 [0/7200 (0%)]
# Train Epoch: 9 [3200/7200 (44%)]
# Train Epoch: 9 [6400/7200 (89%)]
# gradient yy: 0.594732546130105
# gradient yx: 0.09212436260886284
# Average loss: 0.5092
#
# Train Epoch: 10 [0/7200 (0%)]
# Train Epoch: 10 [3200/7200 (44%)]
# Train Epoch: 10 [6400/7200 (89%)]
# gradient yy: 0.5695211655251821
# gradient yx: 0.08751191881650577
# Average loss: 0.5039
#
# Train Epoch: 11 [0/7200 (0%)]
# Train Epoch: 11 [3200/7200 (44%)]
# Train Epoch: 11 [6400/7200 (89%)]
# gradient yy: 0.5473072522682677
# gradient yx: 0.08355816277618719
# Average loss: 0.4985
#
# Train Epoch: 12 [0/7200 (0%)]
# Train Epoch: 12 [3200/7200 (44%)]
# Train Epoch: 12 [6400/7200 (89%)]
# gradient yy: 0.5275697260279758
# gradient yx: 0.0801153714993609
# Average loss: 0.4934
#
# Train Epoch: 13 [0/7200 (0%)]
# Train Epoch: 13 [3200/7200 (44%)]
# Train Epoch: 13 [6400/7200 (89%)]
# gradient yy: 0.5099194469730772
# gradient yx: 0.07704323679446923
# Average loss: 0.4880
#
# Train Epoch: 14 [0/7200 (0%)]
# Train Epoch: 14 [3200/7200 (44%)]
# Train Epoch: 14 [6400/7200 (89%)]
# gradient yy: 0.49406955027596305
# gradient yx: 0.07428492127196155
# Average loss: 0.4830
#
# Train Epoch: 15 [0/7200 (0%)]
# Train Epoch: 15 [3200/7200 (44%)]
# Train Epoch: 15 [6400/7200 (89%)]
# gradient yy: 0.4797430906465694
# gradient yx: 0.07179342707581676
# Average loss: 0.4787
#
# Train Epoch: 16 [0/7200 (0%)]
# Train Epoch: 16 [3200/7200 (44%)]
# Train Epoch: 16 [6400/7200 (89%)]
# gradient yy: 0.46675543611672676
# gradient yx: 0.06949425026562128
# Average loss: 0.4746
#
# Train Epoch: 17 [0/7200 (0%)]
# Train Epoch: 17 [3200/7200 (44%)]
# Train Epoch: 17 [6400/7200 (89%)]
# gradient yy: 0.4549368238943362
# gradient yx: 0.06740515812115631
# Average loss: 0.4715
#
# Train Epoch: 18 [0/7200 (0%)]
# Train Epoch: 18 [3200/7200 (44%)]
# Train Epoch: 18 [6400/7200 (89%)]
# gradient yy: 0.44411234548340034
# gradient yx: 0.06547389635247715
# Average loss: 0.4687
#
# Train Epoch: 19 [0/7200 (0%)]
# Train Epoch: 19 [3200/7200 (44%)]
# Train Epoch: 19 [6400/7200 (89%)]
# gradient yy: 0.43425550440571964
# gradient yx: 0.06366514155849817
# Average loss: 0.4664
#
# Train Epoch: 20 [0/7200 (0%)]
# Train Epoch: 20 [3200/7200 (44%)]
# Train Epoch: 20 [6400/7200 (89%)]
# gradient yy: 0.42500193416018117
# gradient yx: 0.0620862668813226
# Average loss: 0.4649
#
# Train Epoch: 21 [0/7200 (0%)]
# Train Epoch: 21 [3200/7200 (44%)]
# Train Epoch: 21 [6400/7200 (89%)]
# gradient yy: 0.4164442608308825
# gradient yx: 0.060607398085519244
# Average loss: 0.4635
#
# Train Epoch: 22 [0/7200 (0%)]
# Train Epoch: 22 [3200/7200 (44%)]
# Train Epoch: 22 [6400/7200 (89%)]
# gradient yy: 0.4085107231349639
# gradient yx: 0.059239332890889645
# Average loss: 0.4624
#
# Train Epoch: 23 [0/7200 (0%)]
# Train Epoch: 23 [3200/7200 (44%)]
# Train Epoch: 23 [6400/7200 (89%)]
# gradient yy: 0.4010479999903468
# gradient yx: 0.05799475150107809
# Average loss: 0.4615
#
# Train Epoch: 24 [0/7200 (0%)]
# Train Epoch: 24 [3200/7200 (44%)]
# Train Epoch: 24 [6400/7200 (89%)]
# gradient yy: 0.3938483678979008
# gradient yx: 0.056896599333179226
# Average loss: 0.4610
#
# Train Epoch: 25 [0/7200 (0%)]
# Train Epoch: 25 [3200/7200 (44%)]
# Train Epoch: 25 [6400/7200 (89%)]
# gradient yy: 0.387079054496176
# gradient yx: 0.05585464327040444
# Average loss: 0.4604
#
# Train Epoch: 26 [0/7200 (0%)]
# Train Epoch: 26 [3200/7200 (44%)]
# Train Epoch: 26 [6400/7200 (89%)]
# gradient yy: 0.38067652001302754
# gradient yx: 0.05489037119119985
# Average loss: 0.4600
#
# Train Epoch: 27 [0/7200 (0%)]
# Train Epoch: 27 [3200/7200 (44%)]
# Train Epoch: 27 [6400/7200 (89%)]
# gradient yy: 0.37460906560543517
# gradient yx: 0.053978500933566244
# Average loss: 0.4596
#
# Train Epoch: 28 [0/7200 (0%)]
# Train Epoch: 28 [3200/7200 (44%)]
# Train Epoch: 28 [6400/7200 (89%)]
# gradient yy: 0.3688248329867267
# gradient yx: 0.053127045835202176
# Average loss: 0.4592
#
# Train Epoch: 29 [0/7200 (0%)]
# Train Epoch: 29 [3200/7200 (44%)]
# Train Epoch: 29 [6400/7200 (89%)]
# gradient yy: 0.36323668239788487
# gradient yx: 0.05233657002567464
# Average loss: 0.4588
#
# Train Epoch: 30 [0/7200 (0%)]
# Train Epoch: 30 [3200/7200 (44%)]
# Train Epoch: 30 [6400/7200 (89%)]
# gradient yy: 0.35790110952593596
# gradient yx: 0.05158442836598664
# Average loss: 0.4585
#
# Train Epoch: 31 [0/7200 (0%)]
# Train Epoch: 31 [3200/7200 (44%)]
# Train Epoch: 31 [6400/7200 (89%)]
# gradient yy: 0.3527742799505886
# gradient yx: 0.050874903023270156
# Average loss: 0.4582
#
# Train Epoch: 32 [0/7200 (0%)]
# Train Epoch: 32 [3200/7200 (44%)]
# Train Epoch: 32 [6400/7200 (89%)]
# gradient yy: 0.3477951118084701
# gradient yx: 0.05020947471583465
# Average loss: 0.4579
#
# Train Epoch: 33 [0/7200 (0%)]
# Train Epoch: 33 [3200/7200 (44%)]
# Train Epoch: 33 [6400/7200 (89%)]
# gradient yy: 0.34306407914377945
# gradient yx: 0.049568382566937505
# Average loss: 0.4575
#
# Train Epoch: 34 [0/7200 (0%)]
# Train Epoch: 34 [3200/7200 (44%)]
# Train Epoch: 34 [6400/7200 (89%)]
# gradient yy: 0.338479361424535
# gradient yx: 0.048963350956161014
# Average loss: 0.4572
#
# Train Epoch: 35 [0/7200 (0%)]
# Train Epoch: 35 [3200/7200 (44%)]
# Train Epoch: 35 [6400/7200 (89%)]
# gradient yy: 0.33413224420845794
# gradient yx: 0.048372497141199816
# Average loss: 0.4568
#
# Train Epoch: 36 [0/7200 (0%)]
# Train Epoch: 36 [3200/7200 (44%)]
# Train Epoch: 36 [6400/7200 (89%)]
# gradient yy: 0.32996215294228787
# gradient yx: 0.047805353975178495
# Average loss: 0.4565
#
# Train Epoch: 37 [0/7200 (0%)]
# Train Epoch: 37 [3200/7200 (44%)]
# Train Epoch: 37 [6400/7200 (89%)]
# gradient yy: 0.32583120330395277
# gradient yx: 0.04727426515397194
# Average loss: 0.4562
#
# Train Epoch: 38 [0/7200 (0%)]
# Train Epoch: 38 [3200/7200 (44%)]
# Train Epoch: 38 [6400/7200 (89%)]
# gradient yy: 0.3219461749949729
# gradient yx: 0.046746286801868424
# Average loss: 0.4558
#
# Train Epoch: 39 [0/7200 (0%)]
# Train Epoch: 39 [3200/7200 (44%)]
# Train Epoch: 39 [6400/7200 (89%)]
# gradient yy: 0.3182449349144909
# gradient yx: 0.04623548161400054
# Average loss: 0.4555
#
# Train Epoch: 40 [0/7200 (0%)]
# Train Epoch: 40 [3200/7200 (44%)]
# Train Epoch: 40 [6400/7200 (89%)]
# gradient yy: 0.3146527824543825
# gradient yx: 0.04574710431692008
# Average loss: 0.4551
#
# Train Epoch: 41 [0/7200 (0%)]
# Train Epoch: 41 [3200/7200 (44%)]
# Train Epoch: 41 [6400/7200 (89%)]
# gradient yy: 0.3111507028521044
# gradient yx: 0.04527834943695958
# Average loss: 0.4548
#
# Train Epoch: 42 [0/7200 (0%)]
# Train Epoch: 42 [3200/7200 (44%)]
# Train Epoch: 42 [6400/7200 (89%)]
# gradient yy: 0.30779269843117496
# gradient yx: 0.04481893192631095
# Average loss: 0.4545
#
# Train Epoch: 43 [0/7200 (0%)]
# Train Epoch: 43 [3200/7200 (44%)]
# Train Epoch: 43 [6400/7200 (89%)]
# gradient yy: 0.30456137419853224
# gradient yx: 0.04437394987680799
# Average loss: 0.4541
#
# Train Epoch: 44 [0/7200 (0%)]
# Train Epoch: 44 [3200/7200 (44%)]
# Train Epoch: 44 [6400/7200 (89%)]
# gradient yy: 0.3013815200948022
# gradient yx: 0.043952401675985214
# Average loss: 0.4537
#
# Train Epoch: 45 [0/7200 (0%)]
# Train Epoch: 45 [3200/7200 (44%)]
# Train Epoch: 45 [6400/7200 (89%)]
# gradient yy: 0.2982979153399902
# gradient yx: 0.04354449854600191
# Average loss: 0.4533
#
# Train Epoch: 46 [0/7200 (0%)]
# Train Epoch: 46 [3200/7200 (44%)]
# Train Epoch: 46 [6400/7200 (89%)]
# gradient yy: 0.2953807052386036
# gradient yx: 0.04314119263757769
# Average loss: 0.4530
#
# Train Epoch: 47 [0/7200 (0%)]
# Train Epoch: 47 [3200/7200 (44%)]
# Train Epoch: 47 [6400/7200 (89%)]
# gradient yy: 0.2925055083683253
# gradient yx: 0.042757310333147176
# Average loss: 0.4526
#
# Train Epoch: 48 [0/7200 (0%)]
# Train Epoch: 48 [3200/7200 (44%)]
# Train Epoch: 48 [6400/7200 (89%)]
# gradient yy: 0.289695123178282
# gradient yx: 0.04238926639712119
# Average loss: 0.4522
#
# Train Epoch: 49 [0/7200 (0%)]
# Train Epoch: 49 [3200/7200 (44%)]
# Train Epoch: 49 [6400/7200 (89%)]
# gradient yy: 0.28697772087934326
# gradient yx: 0.0420273816226355
# Average loss: 0.4519
#
# Train Epoch: 50 [0/7200 (0%)]
# Train Epoch: 50 [3200/7200 (44%)]
# Train Epoch: 50 [6400/7200 (89%)]
# gradient yy: 0.284476682189328
# gradient yx: 0.04165828399676187
# Average loss: 0.4515
#
#
# Testing on test set
# Average loss: 0.4578

# %%
a = test_data[1:3][:,0]

#a.astype(float)
np.array(list(a))
# Out:
# array([[ 0.90441623,  0.62936389,  0.9118869 ,  0.01697243],
#        [ 1.85885312,  0.92135874, -0.80962511,  0.11318476]])

# %%
test_data_t = torch.Tensor(list(test_data[:][:,0]))
test_y_t = torch.Tensor(list(test_data[:][:,1]))
test_preds = model.forward(test_data_t).detach()

# %%
np.sqrt(((test_y_t - y_pred) ** 2).mean())
# Out:
# tensor(0.2643)

# %%
len(test_loader.dataset)
# Out:
# 2000

# %%
plt.scatter(test_data_t[:,0], test_y_t[:,2])

# %%
test_z = np.array(list(test_data[:][:,0]))[:,0]
test_zdot = test_preds[:,-1]
plt.scatter(test_z, test_zdot)

# %%
direct_test_preds, direct_test_var, direct_test_loss = demo_multi.test_regression(args, model, Myy, Myx, device, test_loader, mean0, var0)

plt.scatter(test_z, direct_test_preds[:,-1])
# Out:
# Average loss: 0.4578

# %%
import seaborn as sns
sns.set(style="darkgrid")
syn_df = pd.DataFrame({
    'Fa_z(N)': direct_test_preds[:, -1],
    'z(m)': test_z
})
g = sns.scatterplot("z(m)", "Fa_z(N)", data=syn_df,
                    #xlim=(-0.2, 3.1), ylim=(-0.5, 2.2),
                    color="b",
                    #height=7,
                    #joint_kws={'alpha': 0.2}
                    alpha=0.2,
                   )

plt.ylim((-0.5, 2.2))
plt.title('Robust Regression (RMSE: 0.265)')
# Out:
# Text(0.5, 1.0, 'Robust Regression (RMSE: 0.265)')

# %%
test_y_t[:,2]
# Out:
# tensor([ 0.3470, -0.0396,  0.2221,  ..., -0.0970,  0.1259, -0.0402])

# %%
import seaborn as sns
sns.set(style="darkgrid")
syn_df = pd.DataFrame({
    'Fa_z error(N)': direct_test_preds[:, -1] - test_y_t[:,2].detach().numpy(),
    'z(m)': test_z
})
g = sns.scatterplot("z(m)", "Fa_z error(N)", data=syn_df,
                    #xlim=(-0.2, 3.1), ylim=(-0.5, 2.2),
                    color="b",
                    #height=7,
                    #joint_kws={'alpha': 0.2}
                    alpha=0.2,
                   )

plt.title('Robust Regression (RMSE: 0.265)')
# Out:
# Text(0.5, 1.0, 'Robust Regression (RMSE: 0.265)')

# %%
np.quantile(direct_test_preds[:, -1] - test_y_t[:,2].detach().numpy(), 0.05)
# Out:
# -0.9951710764541694

# %%
plt.scatter(test_z, y_pred[:, 2])

# %%
test_zdot_gt = np.array(list(test_data[:][:,1]))[:,-1]

plt.scatter(test_z, test_zdot_gt)

# %%
print(__doc__)

# Author: Vincent Dubourg <vincent.dubourg@gmail.com>
#         Jake Vanderplas <vanderplas@astro.washington.edu>
#         Jan Hendrik Metzen <jhm@informatik.uni-bremen.de>s
# License: BSD 3 clause

import numpy as np
from matplotlib import pyplot as plt

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C

np.random.seed(1)
# Out:
# mean0 and var0 is set according to prior knowledge and will not
# affect the result a lot in the no shift case.
# However, if there is shift and target data is far from source,
# base distribution will dominate the result.

# %%
X = inputs.copy()[:1000]
x = np.zeros(X.shape)
x[:,0] = np.linspace(min(X[:,0]),max(X[:,0]), X.shape[0])
Y = dots.copy()[:1000]
dY = (0.5 + 1.0 * np.random.random(Y.shape)) * 0.1
noise = np.random.normal(0, dY)
Y += noise
print(X.shape, Y.shape, x.shape, dY.shape)
# Out:
# (1000, 4) (1000, 3) (1000, 4) (1000, 3)

# %%
n = X.shape[0]
X_train = X[:int(0.8 * n)]
X_test = X[int(0.8 * n):]
Y_train = Y[:int(0.8 * n)]
Y_test = Y[int(0.8 * n):]
dy_train = dY[:int(0.8 * n)]
dy_test = dY[int(0.8 * n):]
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (800, 4) (200, 4) (800, 3) (200, 3)

# %%
# Instantiate a Gaussian Process model
kernel = RBF(0.1)
gp = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp.fit(X_train, Y_train)

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred, sigma = gp.predict(X_test, return_std=True)

# %%
np.sqrt(((Y_test - y_pred) ** 2).mean())
# Out:
# 0.11312010192686324

# %%
plt.scatter(X_test[:,0], y_pred[:,2])

# %%
import seaborn as sns
sns.set(style="darkgrid")
syn_df = pd.DataFrame({
    'Fa_z(N)': y_pred[:,2],
    'z(m)': X_test[:, 0]
})
g = sns.scatterplot("z(m)", "Fa_z(N)", data=syn_df,
                    #xlim=(-0.2, 3.1), ylim=(-0.5, 2.2),
                    color="b",
                    #height=7,
                    #joint_kws={'alpha': 0.2}
                    alpha=0.8,
                   )

plt.ylim((-0.5, 2.2))
plt.title('Gaussian Process (RMSE: 0.120)')
# Out:
# Text(0.5, 1.0, 'Gaussian Process (RMSE: 0.120)')

# %%
np.quantile(y_pred[:,2] - Y_test[:,2], 0.95)
# Out:
# 0.2154571357606839

# %%
plt.scatter(X_train[:,0], Y_train[:,2])

# %%
# Instantiate a Gaussian Process model
gp_0 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)
gp_1 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)
gp_2 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp_0.fit(X_train, Y_train[:,0])
gp_1.fit(X_train, Y_train[:,1])
gp_2.fit(X_train, Y_train[:,2])

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred_0, sigma = gp_0.predict(X_test, return_std=True)
y_pred_1, sigma = gp_1.predict(X_test, return_std=True)
y_pred_2, sigma = gp_2.predict(X_test, return_std=True)

# %%
np.sqrt(((Y_test - np.vstack((y_pred_0, y_pred_1, y_pred_2)).T) ** 2).mean())
# Out:
# 0.11978009622722825

# %%
plt.scatter(X_test[:,0], y_pred[:,-1])

plt.xlabel('z(m)')
plt.ylabel('Fa_z(N)')
plt.title('3D, Synthetic, GP, Test predictions')
# Out:
# Text(0.5, 1.0, '3D, Synthetic, GP, Test predictions')

# %%
plt.scatter(X_train[:,0], Y_train[:,2])
plt.xlabel('z(m)')
plt.ylabel('Fa_z(N)')
plt.title('3D, Synthetic, GP, Training data')
# Out:
# Text(0.5, 1.0, '3D, Synthetic, GP, Training data')

# %%
n_rows = 10000
d_in = 8
d_out = 3
dots = np.zeros((n_rows, 3))
inputs = np.random.random(n_rows * d_in).reshape((n_rows, d_in))
inputs[:,0] *= 3
inputs[:,1:] = inputs[:,1:] * 2 - 1
for i, x in enumerate(inputs):
    a = fa_output(fa_model=fa_model, height=x[0],
                  velocity=x[1:4], controls=x[4:])
    dots[i] = a[0].detach().numpy()

# %%
class Args:
    pass

use_cuda = False
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

batch_size = 32
epochs_training = 50
lr = 0.0005
momentum = 0.5
log_interval = 100
lamb = 0.001

args = Args()
args.batch_size = batch_size
args.epochs_training = epochs_training
args.lr = lr
args.momentum = momentum
args.log_interval = log_interval
split_data = SplitData(inputs, dots)

# %%
split_data = np.random.permutation(split_data)
train_data = data.Subset(split_data, range(0, int(0.8*len(split_data))))
# 20% test set
test_data = data.Subset(split_data, range(int(0.8*len(split_data)), len(split_data)))

m_train = len(train_data)

# for covariate shift, plug in densities for source data
weight_st = np.ones(m_train)
    
weighted_train = WeightDataSet(train_data, weight_st)
m_test = len(test_data)

# for covariate shift, plug in densities for target data
weight_st = np.ones(m_test)
weighted_test = WeightDataSet(test_data, weight_st)


test_loader = data.DataLoader(weighted_test,
    batch_size=args.batch_size, shuffle=False, **kwargs)

# 10% of training as validation
m_validate = int(0.1*m_train)

validate_loader = data.DataLoader(data.Subset(weighted_train,range(0, m_validate)),
    batch_size=args.batch_size, shuffle=False, **kwargs)

# 10% validation set, note that under shift cases, cannot valiate using training data
train_loader = data.DataLoader(data.Subset(weighted_train, range(m_validate, m_train)),
    batch_size=args.batch_size, shuffle=False, **kwargs)

base_model = Net(d_in, 256, d)
base_model = base_model.to(device)

print("entering training")
model, Myy, Myx, y_pred, y_var, _  = train_validate_test(
    args, args.epochs_training, device, use_cuda, base_model, 
    train_loader, test_loader , validate_loader, lamb)
# Out:
# entering training
# Train Epoch: 1 [0/7200 (0%)]
# Train Epoch: 1 [3200/7200 (44%)]
# Train Epoch: 1 [6400/7200 (89%)]
# gradient yy: 1.0702784624848605
# gradient yx: 0.7778483329606289
# Average loss: 0.1733
#
# Train Epoch: 2 [0/7200 (0%)]
# Train Epoch: 2 [3200/7200 (44%)]
# Train Epoch: 2 [6400/7200 (89%)]
# gradient yy: 0.9147474358049016
# gradient yx: 0.6069426786058438
# Average loss: 0.1557
#
# Train Epoch: 3 [0/7200 (0%)]
# Train Epoch: 3 [3200/7200 (44%)]
# Train Epoch: 3 [6400/7200 (89%)]
# gradient yy: 0.8111744174642268
# gradient yx: 0.4789140165271745
# Average loss: 0.1441
#
# Train Epoch: 4 [0/7200 (0%)]
# Train Epoch: 4 [3200/7200 (44%)]
# Train Epoch: 4 [6400/7200 (89%)]
# gradient yy: 0.7426366927420498
# gradient yx: 0.38679746719505903
# Average loss: 0.1365
#
# Train Epoch: 5 [0/7200 (0%)]
# Train Epoch: 5 [3200/7200 (44%)]
# Train Epoch: 5 [6400/7200 (89%)]
# gradient yy: 0.6947805819472846
# gradient yx: 0.32184916195837554
# Average loss: 0.1313
#
# Train Epoch: 6 [0/7200 (0%)]
# Train Epoch: 6 [3200/7200 (44%)]
# Train Epoch: 6 [6400/7200 (89%)]
# gradient yy: 0.6578984612123695
# gradient yx: 0.2758376940209634
# Average loss: 0.1274
#
# Train Epoch: 7 [0/7200 (0%)]
# Train Epoch: 7 [3200/7200 (44%)]
# Train Epoch: 7 [6400/7200 (89%)]
# gradient yy: 0.6270238525253959
# gradient yx: 0.24259780436225403
# Average loss: 0.1240
#
# Train Epoch: 8 [0/7200 (0%)]
# Train Epoch: 8 [3200/7200 (44%)]
# Train Epoch: 8 [6400/7200 (89%)]
# gradient yy: 0.5999176169099809
# gradient yx: 0.21796020497836668
# Average loss: 0.1209
#
# Train Epoch: 9 [0/7200 (0%)]
# Train Epoch: 9 [3200/7200 (44%)]
# Train Epoch: 9 [6400/7200 (89%)]
# gradient yy: 0.5755393070139938
# gradient yx: 0.19928031561749135
# Average loss: 0.1179
#
# Train Epoch: 10 [0/7200 (0%)]
# Train Epoch: 10 [3200/7200 (44%)]
# Train Epoch: 10 [6400/7200 (89%)]
# gradient yy: 0.5533873629217194
# gradient yx: 0.18488223207161258
# Average loss: 0.1148
#
# Train Epoch: 11 [0/7200 (0%)]
# Train Epoch: 11 [3200/7200 (44%)]
# Train Epoch: 11 [6400/7200 (89%)]
# gradient yy: 0.5328232834286205
# gradient yx: 0.1733923176850528
# Average loss: 0.1117
#
# Train Epoch: 12 [0/7200 (0%)]
# Train Epoch: 12 [3200/7200 (44%)]
# Train Epoch: 12 [6400/7200 (89%)]
# gradient yy: 0.5137545790856166
# gradient yx: 0.16418186402621254
# Average loss: 0.1086
#
# Train Epoch: 13 [0/7200 (0%)]
# Train Epoch: 13 [3200/7200 (44%)]
# Train Epoch: 13 [6400/7200 (89%)]
# gradient yy: 0.49619123685457645
# gradient yx: 0.15662178946521735
# Average loss: 0.1059
#
# Train Epoch: 14 [0/7200 (0%)]
# Train Epoch: 14 [3200/7200 (44%)]
# Train Epoch: 14 [6400/7200 (89%)]
# gradient yy: 0.4800673887822884
# gradient yx: 0.150280901973678
# Average loss: 0.1035
#
# Train Epoch: 15 [0/7200 (0%)]
# Train Epoch: 15 [3200/7200 (44%)]
# Train Epoch: 15 [6400/7200 (89%)]
# gradient yy: 0.4655451845582293
# gradient yx: 0.14496000384913613
# Average loss: 0.1016
#
# Train Epoch: 16 [0/7200 (0%)]
# Train Epoch: 16 [3200/7200 (44%)]
# Train Epoch: 16 [6400/7200 (89%)]
# gradient yy: 0.45242473735511257
# gradient yx: 0.14031599361936464
# Average loss: 0.1001
#
# Train Epoch: 17 [0/7200 (0%)]
# Train Epoch: 17 [3200/7200 (44%)]
# Train Epoch: 17 [6400/7200 (89%)]
# gradient yy: 0.4405612168177168
# gradient yx: 0.13618230933209408
# Average loss: 0.0988
#
# Train Epoch: 18 [0/7200 (0%)]
# Train Epoch: 18 [3200/7200 (44%)]
# Train Epoch: 18 [6400/7200 (89%)]
# gradient yy: 0.42986254456863987
# gradient yx: 0.13264659533368045
# Average loss: 0.0978
#
# Train Epoch: 19 [0/7200 (0%)]
# Train Epoch: 19 [3200/7200 (44%)]
# Train Epoch: 19 [6400/7200 (89%)]
# gradient yy: 0.42011823912935264
# gradient yx: 0.12936783001003693
# Average loss: 0.0970
#
# Train Epoch: 20 [0/7200 (0%)]
# Train Epoch: 20 [3200/7200 (44%)]
# Train Epoch: 20 [6400/7200 (89%)]
# gradient yy: 0.4111803149663761
# gradient yx: 0.12640474376426059
# Average loss: 0.0963
#
# Train Epoch: 21 [0/7200 (0%)]
# Train Epoch: 21 [3200/7200 (44%)]
# Train Epoch: 21 [6400/7200 (89%)]
# gradient yy: 0.4028651694927007
# gradient yx: 0.12374470744227535
# Average loss: 0.0958
#
# Train Epoch: 22 [0/7200 (0%)]
# Train Epoch: 22 [3200/7200 (44%)]
# Train Epoch: 22 [6400/7200 (89%)]
# gradient yy: 0.39518049735352245
# gradient yx: 0.12128081159495199
# Average loss: 0.0953
#
# Train Epoch: 23 [0/7200 (0%)]
# Train Epoch: 23 [3200/7200 (44%)]
# Train Epoch: 23 [6400/7200 (89%)]
# gradient yy: 0.3880207673815905
# gradient yx: 0.11887198200434118
# Average loss: 0.0949
#
# Train Epoch: 24 [0/7200 (0%)]
# Train Epoch: 24 [3200/7200 (44%)]
# Train Epoch: 24 [6400/7200 (89%)]
# gradient yy: 0.3811703618288511
# gradient yx: 0.11665001445073567
# Average loss: 0.0945
#
# Train Epoch: 25 [0/7200 (0%)]
# Train Epoch: 25 [3200/7200 (44%)]
# Train Epoch: 25 [6400/7200 (89%)]
# gradient yy: 0.37477619740272694
# gradient yx: 0.11458157102635183
# Average loss: 0.0942
#
# Train Epoch: 26 [0/7200 (0%)]
# Train Epoch: 26 [3200/7200 (44%)]
# Train Epoch: 26 [6400/7200 (89%)]
# gradient yy: 0.3687035513269237
# gradient yx: 0.11257508208365136
# Average loss: 0.0939
#
# Train Epoch: 27 [0/7200 (0%)]
# Train Epoch: 27 [3200/7200 (44%)]
# Train Epoch: 27 [6400/7200 (89%)]
# gradient yy: 0.36283559605873994
# gradient yx: 0.11066496575290645
# Average loss: 0.0936
#
# Train Epoch: 28 [0/7200 (0%)]
# Train Epoch: 28 [3200/7200 (44%)]
# Train Epoch: 28 [6400/7200 (89%)]
# gradient yy: 0.35740246273209253
# gradient yx: 0.10883350206913406
# Average loss: 0.0934
#
# Train Epoch: 29 [0/7200 (0%)]
# Train Epoch: 29 [3200/7200 (44%)]
# Train Epoch: 29 [6400/7200 (89%)]
# gradient yy: 0.3521475211797443
# gradient yx: 0.10708725663474762
# Average loss: 0.0932
#
# Train Epoch: 30 [0/7200 (0%)]
# Train Epoch: 30 [3200/7200 (44%)]
# Train Epoch: 30 [6400/7200 (89%)]
# gradient yy: 0.347183201423318
# gradient yx: 0.10541143171992663
# Average loss: 0.0929
#
# Train Epoch: 31 [0/7200 (0%)]
# Train Epoch: 31 [3200/7200 (44%)]
# Train Epoch: 31 [6400/7200 (89%)]
# gradient yy: 0.34243779036353394
# gradient yx: 0.10379597102534947
# Average loss: 0.0927
#
# Train Epoch: 32 [0/7200 (0%)]
# Train Epoch: 32 [3200/7200 (44%)]
# Train Epoch: 32 [6400/7200 (89%)]
# gradient yy: 0.33788099956264683
# gradient yx: 0.10225597637577133
# Average loss: 0.0925
#
# Train Epoch: 33 [0/7200 (0%)]
# Train Epoch: 33 [3200/7200 (44%)]
# Train Epoch: 33 [6400/7200 (89%)]
# gradient yy: 0.3335901951275793
# gradient yx: 0.10076484682564514
# Average loss: 0.0923
#
# Train Epoch: 34 [0/7200 (0%)]
# Train Epoch: 34 [3200/7200 (44%)]
# Train Epoch: 34 [6400/7200 (89%)]
# gradient yy: 0.32941737040408714
# gradient yx: 0.09933440220010831
# Average loss: 0.0922
#
# Train Epoch: 35 [0/7200 (0%)]
# Train Epoch: 35 [3200/7200 (44%)]
# Train Epoch: 35 [6400/7200 (89%)]
# gradient yy: 0.3254702558206879
# gradient yx: 0.09796746363151783
# Average loss: 0.0920
#
# Train Epoch: 36 [0/7200 (0%)]
# Train Epoch: 36 [3200/7200 (44%)]
# Train Epoch: 36 [6400/7200 (89%)]
# gradient yy: 0.3216788643847116
# gradient yx: 0.09664530193727344
# Average loss: 0.0918
#
# Train Epoch: 37 [0/7200 (0%)]
# Train Epoch: 37 [3200/7200 (44%)]
# Train Epoch: 37 [6400/7200 (89%)]
# gradient yy: 0.31800911818815064
# gradient yx: 0.09538577867488945
# Average loss: 0.0916
#
# Train Epoch: 38 [0/7200 (0%)]
# Train Epoch: 38 [3200/7200 (44%)]
# Train Epoch: 38 [6400/7200 (89%)]
# gradient yy: 0.3145271805045444
# gradient yx: 0.09417631468335023
# Average loss: 0.0915
#
# Train Epoch: 39 [0/7200 (0%)]
# Train Epoch: 39 [3200/7200 (44%)]
# Train Epoch: 39 [6400/7200 (89%)]
# gradient yy: 0.3111519849368304
# gradient yx: 0.09300389742298355
# Average loss: 0.0913
#
# Train Epoch: 40 [0/7200 (0%)]
# Train Epoch: 40 [3200/7200 (44%)]
# Train Epoch: 40 [6400/7200 (89%)]
# gradient yy: 0.3078968278051855
# gradient yx: 0.09187892458397479
# Average loss: 0.0911
#
# Train Epoch: 41 [0/7200 (0%)]
# Train Epoch: 41 [3200/7200 (44%)]
# Train Epoch: 41 [6400/7200 (89%)]
# gradient yy: 0.3047680208346543
# gradient yx: 0.09079808069201567
# Average loss: 0.0910
#
# Train Epoch: 42 [0/7200 (0%)]
# Train Epoch: 42 [3200/7200 (44%)]
# Train Epoch: 42 [6400/7200 (89%)]
# gradient yy: 0.3017548519601782
# gradient yx: 0.08976540653250764
# Average loss: 0.0908
#
# Train Epoch: 43 [0/7200 (0%)]
# Train Epoch: 43 [3200/7200 (44%)]
# Train Epoch: 43 [6400/7200 (89%)]
# gradient yy: 0.2988980880282577
# gradient yx: 0.0887733979114611
# Average loss: 0.0907
#
# Train Epoch: 44 [0/7200 (0%)]
# Train Epoch: 44 [3200/7200 (44%)]
# Train Epoch: 44 [6400/7200 (89%)]
# gradient yy: 0.29611697615660226
# gradient yx: 0.08780479011755989
# Average loss: 0.0905
#
# Train Epoch: 45 [0/7200 (0%)]
# Train Epoch: 45 [3200/7200 (44%)]
# Train Epoch: 45 [6400/7200 (89%)]
# gradient yy: 0.29340943531300995
# gradient yx: 0.08687638377635203
# Average loss: 0.0904
#
# Train Epoch: 46 [0/7200 (0%)]
# Train Epoch: 46 [3200/7200 (44%)]
# Train Epoch: 46 [6400/7200 (89%)]
# gradient yy: 0.29082896529697894
# gradient yx: 0.08598515197592461
# Average loss: 0.0902
#
# Train Epoch: 47 [0/7200 (0%)]
# Train Epoch: 47 [3200/7200 (44%)]
# Train Epoch: 47 [6400/7200 (89%)]
# gradient yy: 0.288268424631286
# gradient yx: 0.08513395971776695
# Average loss: 0.0901
#
# Train Epoch: 48 [0/7200 (0%)]
# Train Epoch: 48 [3200/7200 (44%)]
# Train Epoch: 48 [6400/7200 (89%)]
# gradient yy: 0.2858500987115717
# gradient yx: 0.08431009907974417
# Average loss: 0.0900
#
# Train Epoch: 49 [0/7200 (0%)]
# Train Epoch: 49 [3200/7200 (44%)]
# Train Epoch: 49 [6400/7200 (89%)]
# gradient yy: 0.28354204435995023
# gradient yx: 0.08349060827266686
# Average loss: 0.0899
#
# Train Epoch: 50 [0/7200 (0%)]
# Train Epoch: 50 [3200/7200 (44%)]
# Train Epoch: 50 [6400/7200 (89%)]
# gradient yy: 0.2811878100116107
# gradient yx: 0.08272593778944279
# Average loss: 0.0897
#
#
# Testing on test set
# Average loss: 0.0950

# %%
n = len(dots)
np.sqrt(((dots[int(len(dots) * 0.8):] - y_pred) ** 2).mean())
# Out:
# 0.49937819795106864

# %%
X = inputs.copy()[:1000]
x = np.zeros(X.shape)
x[:,0] = np.linspace(min(X[:,0]),max(X[:,0]), X.shape[0])
Y = dots.copy()[:1000]
dY = (0.5 + 1.0 * np.random.random(Y.shape)) * 0.1
noise = np.random.normal(0, dY)
Y += noise
print(X.shape, Y.shape, x.shape, dY.shape)
# Out:
# (1000, 8) (1000, 3) (1000, 8) (1000, 3)

# %%
n = X.shape[0]
X_train = X[:int(0.8 * n)]
X_test = X[int(0.8 * n):]
Y_train = Y[:int(0.8 * n)]
Y_test = Y[int(0.8 * n):]
dy_train = dY[:int(0.8 * n)]
dy_test = dY[int(0.8 * n):]
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (800, 8) (200, 8) (800, 3) (200, 3)

# %%
# Instantiate a Gaussian Process model
kernel = RBF(0.01)
gp = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp.fit(X_train, Y_train)

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred, sigma = gp.predict(X_test, return_std=True)

# %%
np.sqrt(((Y_test - y_pred) ** 2).mean())
# Out:
# 0.14223583163742826

# %%
# Instantiate a Gaussian Process model
gp_0 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)
gp_1 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)
gp_2 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp_0.fit(X_train, Y_train[:,0])
gp_1.fit(X_train, Y_train[:,1])
gp_2.fit(X_train, Y_train[:,2])

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred_0, sigma = gp_0.predict(X_test, return_std=True)
y_pred_1, sigma = gp_1.predict(X_test, return_std=True)
y_pred_2, sigma = gp_2.predict(X_test, return_std=True)

# %%
np.sqrt(((Y_test - np.vstack((y_pred_0, y_pred_1, y_pred_2)).T) ** 2).mean())
# Out:
# 0.13946106913603606

# %%
plt.scatter(X_test[:,0], y_pred[:,-1])

plt.xlabel('z(m)')
plt.ylabel('Fa_z(N)')
plt.title('3D, Synthetic, GP, Test predictions')
# Out:
# Text(0.5, 1.0, '3D, Synthetic, GP, Test predictions')

# %%
plt.scatter(X_train[:,0], Y_train[:,2])
plt.xlabel('z(m)')
plt.ylabel('Fa_z(N)')
plt.title('3D, Synthetic, GP, Training data')
# Out:
# Text(0.5, 1.0, '3D, Synthetic, GP, Training data')
