# %%
from __future__ import print_function
import pandas as pd
import os
import matplotlib.pyplot as plt

import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import torchvision
import torch.utils.data as data
import os
import copy
torch.set_default_tensor_type('torch.DoubleTensor')

import demo_multi
import importlib
importlib.reload(demo_multi)
from demo_multi import SplitData, train_validate_test, WeightDataSet, \
    Net, test_regression
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
df = pd.read_csv('Fa_data.csv')

# %%
df.columns
# Out:
# Index(['time(s)', ' Fa_x(N)', ' Fa_y(N)', ' Fa_z(N)', ' x(m)', ' y(m)',
#        ' z(m)', ' v_x(m/s)', ' v_y(m/s)', ' v_z(m/s)', ' quaternion_x',
#        ' quaternion_y', ' quaternion_z', ' quaternion_w', ' u_1(RPM)',
#        ' u_2(RPM)', ' u_3(RPM)', ' u_4(RPM)'],
#       dtype='object')

# %%
df.columns = list(map(str.strip, df.columns))

# %%
df['Fa_x(N)'].plot()

# %%
df['Fa_y(N)'].plot()

# %%
df['Fa_z(N)'].plot(style='o', alpha=0.05)

# %%
df['z(m)'].plot()
plt.ylabel('z(m)')
plt.xlabel('Time')
plt.title('Real dataset Ground Truth')
# Out:
# Text(0.5, 1.0, 'Real dataset Ground Truth')

# %%
plt.scatter(df['z(m)'], df['Fa_z(N)'], alpha=0.1)

# %%
import seaborn as sns
sns.set(style="darkgrid")

# tips = sns.load_dataset("tips")
# g = sns.jointplot("total_bill", "tip", data=tips,
#                   kind="reg", truncate=False,
#                   xlim=(0, 60), ylim=(0, 12),
#                   color="m", height=7)
g = sns.jointplot("z(m)", "Fa_z(N)", data=df,
                  #kind="scatter",
                  xlim=(0, 4), ylim=(-6, 6),
                  color="b", height=7, joint_kws={'alpha': 0.2})

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
class Network(nn.Module):

    def __init__(self):
        super(Network, self).__init__()
        self.fc1 = nn.Linear(12, 25)
        self.fc2 = nn.Linear(25, 30)
        self.fc3 = nn.Linear(30, 15)
        self.fc4 = nn.Linear(15, 3)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)

        return x

def read_weight(filename):
    model_weight = torch.load(filename)
    model = Network()
    model.load_state_dict(model_weight)
    return model

# %%
fa_model = read_weight('Fa_net_12_3_full_Lip16.pth')

# %%
# state is a 12-d vector
# 0: height, z
# 1,2,3: velocity, \dot{x}, \dot{y}, \dot{z}
# 4,5,6,7: quaternion, qx, qy, qz, qw
# 8,9,10,11: control, u1, u2, u3, u4

# input range and constraints
# 0 <= z <= 1.5
# -1 <= \dot{x,y,z} <= 1 
# qx^2 + qy^2 + qz^2 + qw^2 = 1
# 0 <= u1,u2,u3,u4 <= 1

# *******************************************
# Task 1: learn a 4d -> 3d function
# fix qx,qy,qz,qw = 0,0,0,1
# fix u1,u2,u3,u4 = 0.7,0.7,0.7,0.7
# learn the function (z,\dot{x},\dot{y},\dot{z}) -> fa
def fa_output(fa_model, height, velocity, controls=[0.7] * 4):
    state = np.zeros([1, 12])
    state[0, 0] = height
    state[0, 1:4] = velocity
    state[0, 7] = 1.0
    state[0, 8:12] = controls
    state_torch = torch.from_numpy(state)
    #print(state_torch)
    Fa = fa_model(state_torch)
    return Fa

# %%
print(fa_output(fa_model=fa_model, height=0.2, velocity=np.array([0,0,0])))

# *******************************************
# Task 2: learn a 8d -> 3d function
# fix qx,qy,qz,qw = 0,0,0,1
# learn the function (z,\dot{x},\dot{y},\dot{z},u1,u2,u3,u4) -> fa
# Out:
# tensor([[0.2861, 0.0693, 1.3686]], grad_fn=<AddmmBackward>)

# %%
df.columns
# Out:
# Index(['time(s)', 'Fa_x(N)', 'Fa_y(N)', 'Fa_z(N)', 'x(m)', 'y(m)', 'z(m)',
#        'v_x(m/s)', 'v_y(m/s)', 'v_z(m/s)', 'quaternion_x', 'quaternion_y',
#        'quaternion_z', 'quaternion_w', 'u_1(RPM)', 'u_2(RPM)', 'u_3(RPM)',
#        'u_4(RPM)'],
#       dtype='object')

# %%
inputs = df[[
    'z(m)',
    'v_x(m/s)',
    'v_y(m/s)',
    'v_z(m/s)',
]].values
dots = df[[
    'Fa_x(N)',
    'Fa_y(N)',
    'Fa_z(N)'
]].values

# %%
len(inputs)
# Out:
# 28983

# %%
# inputs = inputs[:7200]
# dots = dots[:7200]

# %%
# randomize
# index = np.random.permutation(len(inputs))
# inputs = inputs[index]
# dots = dots[index]

# %%
plt.plot(dots[:,2])

# %%
plt.plot(dots[:,1])

# %%
plt.plot(dots[:,0])

# %%
plt.scatter(inputs[:,0], dots[:,2], alpha=0.1)

# %%
'''
d is the dimension of the last layer of network

'''

d = 10

'''
d_out is the dimension of the output variable

'''

d_out = 3


'''
mean0 and var0 is set according to prior knowledge and will not
affect the result a lot in the no shift case.
However, if there is shift and target data is far from source,
base distribution will dominate the result.

'''

mean0 = np.zeros([1, d_out])
var0 = np.eye(d_out)

# %%
class Args:
    pass

use_cuda = False
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}


batch_size = 32
epochs_training = 25
lr = 0.0005
momentum = 0.5
log_interval = 100
lamb = 0.001

args = Args()
args.batch_size = batch_size
args.epochs_training = epochs_training
args.lr = lr
args.momentum = momentum
args.log_interval = log_interval

# %%
split_data = SplitData(inputs, dots)

# %%
#split_data = np.random.permutation(split_data)
train_data = data.Subset(split_data, range(0, int(0.8*len(split_data))))
# 20% test set
test_data = data.Subset(split_data, range(int(0.8*len(split_data)), len(split_data)))

m_train = len(train_data)

# for covariate shift, plug in densities for source data
weight_st = np.ones(m_train)
    
weighted_train = WeightDataSet(train_data, weight_st)
m_test = len(test_data)

# for covariate shift, plug in densities for target data
weight_st = np.ones(m_test)
weighted_test = WeightDataSet(test_data, weight_st)


test_loader = data.DataLoader(weighted_test,
    batch_size=args.batch_size, shuffle=False, **kwargs)

# 10% of training as validation
m_validate = int(0.1*m_train)

validate_loader = data.DataLoader(data.Subset(weighted_train,range(0, m_validate)),
    batch_size=args.batch_size, shuffle=False, **kwargs)

# 10% validation set, note that under shift cases, cannot valiate using training data
train_loader = data.DataLoader(data.Subset(weighted_train, range(m_validate, m_train)),
    batch_size=args.batch_size, shuffle=False, **kwargs)

base_model = Net(4,256, d)
base_model = base_model.to(device)

print("entering training")
model, Myy, Myx, y_pred, y_var, _  = train_validate_test(
    args, args.epochs_training, device, use_cuda, base_model, 
    train_loader, test_loader , validate_loader, lamb)
# Out:
# entering training
# Train Epoch: 1 [0/20868 (0%)]
# Train Epoch: 1 [3200/20868 (15%)]
# Train Epoch: 1 [6400/20868 (31%)]
# Train Epoch: 1 [9600/20868 (46%)]
# Train Epoch: 1 [12800/20868 (61%)]
# Train Epoch: 1 [16000/20868 (77%)]
# Train Epoch: 1 [19200/20868 (92%)]
# gradient yy: 0.7340283421120701
# gradient yx: 0.379154099146944
# Average loss: 1.1979
#
# Train Epoch: 2 [0/20868 (0%)]
# Train Epoch: 2 [3200/20868 (15%)]
# Train Epoch: 2 [6400/20868 (31%)]
# Train Epoch: 2 [9600/20868 (46%)]
# Train Epoch: 2 [12800/20868 (61%)]
# Train Epoch: 2 [16000/20868 (77%)]
# Train Epoch: 2 [19200/20868 (92%)]
# gradient yy: 0.5251836888842724
# gradient yx: 0.1766258654482128
# Average loss: 1.2077
#
# Train Epoch: 3 [0/20868 (0%)]
# Train Epoch: 3 [3200/20868 (15%)]
# Train Epoch: 3 [6400/20868 (31%)]
# Train Epoch: 3 [9600/20868 (46%)]
# Train Epoch: 3 [12800/20868 (61%)]
# Train Epoch: 3 [16000/20868 (77%)]
# Train Epoch: 3 [19200/20868 (92%)]
# gradient yy: 0.423785613669623
# gradient yx: 0.11906934707604715
# Average loss: 1.1994
#
# Train Epoch: 4 [0/20868 (0%)]
# Train Epoch: 4 [3200/20868 (15%)]
# Train Epoch: 4 [6400/20868 (31%)]
# Train Epoch: 4 [9600/20868 (46%)]
# Train Epoch: 4 [12800/20868 (61%)]
# Train Epoch: 4 [16000/20868 (77%)]
# Train Epoch: 4 [19200/20868 (92%)]
# gradient yy: 0.35446063789639015
# gradient yx: 0.09689445805189331
# Average loss: 1.1882
#
# Train Epoch: 5 [0/20868 (0%)]
# Train Epoch: 5 [3200/20868 (15%)]
# Train Epoch: 5 [6400/20868 (31%)]
# Train Epoch: 5 [9600/20868 (46%)]
# Train Epoch: 5 [12800/20868 (61%)]
# Train Epoch: 5 [16000/20868 (77%)]
# Train Epoch: 5 [19200/20868 (92%)]
# gradient yy: 0.29986014269837574
# gradient yx: 0.08312029905856459
# Average loss: 1.1800
#
# Train Epoch: 6 [0/20868 (0%)]
# Train Epoch: 6 [3200/20868 (15%)]
# Train Epoch: 6 [6400/20868 (31%)]
# Train Epoch: 6 [9600/20868 (46%)]
# Train Epoch: 6 [12800/20868 (61%)]
# Train Epoch: 6 [16000/20868 (77%)]
# Train Epoch: 6 [19200/20868 (92%)]
# gradient yy: 0.25809473580004405
# gradient yx: 0.07283137343976603
# Average loss: 1.1746
#
# Train Epoch: 7 [0/20868 (0%)]
# Train Epoch: 7 [3200/20868 (15%)]
# Train Epoch: 7 [6400/20868 (31%)]
# Train Epoch: 7 [9600/20868 (46%)]
# Train Epoch: 7 [12800/20868 (61%)]
# Train Epoch: 7 [16000/20868 (77%)]
# Train Epoch: 7 [19200/20868 (92%)]
# gradient yy: 0.22769480877664058
# gradient yx: 0.06584818581273749
# Average loss: 1.1715
#
# Train Epoch: 8 [0/20868 (0%)]
# Train Epoch: 8 [3200/20868 (15%)]
# Train Epoch: 8 [6400/20868 (31%)]
# Train Epoch: 8 [9600/20868 (46%)]
# Train Epoch: 8 [12800/20868 (61%)]
# Train Epoch: 8 [16000/20868 (77%)]
# Train Epoch: 8 [19200/20868 (92%)]
# gradient yy: 0.20552214032288713
# gradient yx: 0.06125630715206061
# Average loss: 1.1691
#
# Train Epoch: 9 [0/20868 (0%)]
# Train Epoch: 9 [3200/20868 (15%)]
# Train Epoch: 9 [6400/20868 (31%)]
# Train Epoch: 9 [9600/20868 (46%)]
# Train Epoch: 9 [12800/20868 (61%)]
# Train Epoch: 9 [16000/20868 (77%)]
# Train Epoch: 9 [19200/20868 (92%)]
# gradient yy: 0.18823437657253952
# gradient yx: 0.0577112790802387
# Average loss: 1.1665
#
# Train Epoch: 10 [0/20868 (0%)]
# Train Epoch: 10 [3200/20868 (15%)]
# Train Epoch: 10 [6400/20868 (31%)]
# Train Epoch: 10 [9600/20868 (46%)]
# Train Epoch: 10 [12800/20868 (61%)]
# Train Epoch: 10 [16000/20868 (77%)]
# Train Epoch: 10 [19200/20868 (92%)]
# gradient yy: 0.1737337389794888
# gradient yx: 0.05472313655412169
# Average loss: 1.1640
#
# Train Epoch: 11 [0/20868 (0%)]
# Train Epoch: 11 [3200/20868 (15%)]
# Train Epoch: 11 [6400/20868 (31%)]
# Train Epoch: 11 [9600/20868 (46%)]
# Train Epoch: 11 [12800/20868 (61%)]
# Train Epoch: 11 [16000/20868 (77%)]
# Train Epoch: 11 [19200/20868 (92%)]
# gradient yy: 0.16126619386265792
# gradient yx: 0.05201618589484003
# Average loss: 1.1619
#
# Train Epoch: 12 [0/20868 (0%)]
# Train Epoch: 12 [3200/20868 (15%)]
# Train Epoch: 12 [6400/20868 (31%)]
# Train Epoch: 12 [9600/20868 (46%)]
# Train Epoch: 12 [12800/20868 (61%)]
# Train Epoch: 12 [16000/20868 (77%)]
# Train Epoch: 12 [19200/20868 (92%)]
# gradient yy: 0.15052783573478262
# gradient yx: 0.049681979756447496
# Average loss: 1.1600
#
# Train Epoch: 13 [0/20868 (0%)]
# Train Epoch: 13 [3200/20868 (15%)]
# Train Epoch: 13 [6400/20868 (31%)]
# Train Epoch: 13 [9600/20868 (46%)]
# Train Epoch: 13 [12800/20868 (61%)]
# Train Epoch: 13 [16000/20868 (77%)]
# Train Epoch: 13 [19200/20868 (92%)]
# gradient yy: 0.14149173150427358
# gradient yx: 0.04768523399950678
# Average loss: 1.1583
#
# Train Epoch: 14 [0/20868 (0%)]
# Train Epoch: 14 [3200/20868 (15%)]
# Train Epoch: 14 [6400/20868 (31%)]
# Train Epoch: 14 [9600/20868 (46%)]
# Train Epoch: 14 [12800/20868 (61%)]
# Train Epoch: 14 [16000/20868 (77%)]
# Train Epoch: 14 [19200/20868 (92%)]
# gradient yy: 0.1334246373727176
# gradient yx: 0.0459217929123189
# Average loss: 1.1566
#
# Train Epoch: 15 [0/20868 (0%)]
# Train Epoch: 15 [3200/20868 (15%)]
# Train Epoch: 15 [6400/20868 (31%)]
# Train Epoch: 15 [9600/20868 (46%)]
# Train Epoch: 15 [12800/20868 (61%)]
# Train Epoch: 15 [16000/20868 (77%)]
# Train Epoch: 15 [19200/20868 (92%)]
# gradient yy: 0.12614411156812938
# gradient yx: 0.044259340424342986
# Average loss: 1.1551
#
# Train Epoch: 16 [0/20868 (0%)]
# Train Epoch: 16 [3200/20868 (15%)]
# Train Epoch: 16 [6400/20868 (31%)]
# Train Epoch: 16 [9600/20868 (46%)]
# Train Epoch: 16 [12800/20868 (61%)]
# Train Epoch: 16 [16000/20868 (77%)]
# Train Epoch: 16 [19200/20868 (92%)]
# gradient yy: 0.11953658089822261
# gradient yx: 0.04270605679180768
# Average loss: 1.1536
#
# Train Epoch: 17 [0/20868 (0%)]
# Train Epoch: 17 [3200/20868 (15%)]
# Train Epoch: 17 [6400/20868 (31%)]
# Train Epoch: 17 [9600/20868 (46%)]
# Train Epoch: 17 [12800/20868 (61%)]
# Train Epoch: 17 [16000/20868 (77%)]
# Train Epoch: 17 [19200/20868 (92%)]
# gradient yy: 0.11366754972945785
# gradient yx: 0.04138446912162642
# Average loss: 1.1524
#
# Train Epoch: 18 [0/20868 (0%)]
# Train Epoch: 18 [3200/20868 (15%)]
# Train Epoch: 18 [6400/20868 (31%)]
# Train Epoch: 18 [9600/20868 (46%)]
# Train Epoch: 18 [12800/20868 (61%)]
# Train Epoch: 18 [16000/20868 (77%)]
# Train Epoch: 18 [19200/20868 (92%)]
# gradient yy: 0.1084193705118429
# gradient yx: 0.04025661296476076
# Average loss: 1.1512
#
# Train Epoch: 19 [0/20868 (0%)]
# Train Epoch: 19 [3200/20868 (15%)]
# Train Epoch: 19 [6400/20868 (31%)]
# Train Epoch: 19 [9600/20868 (46%)]
# Train Epoch: 19 [12800/20868 (61%)]
# Train Epoch: 19 [16000/20868 (77%)]
# Train Epoch: 19 [19200/20868 (92%)]
# gradient yy: 0.10358789113446677
# gradient yx: 0.039220926239616406
# Average loss: 1.1502
#
# Train Epoch: 20 [0/20868 (0%)]
# Train Epoch: 20 [3200/20868 (15%)]
# Train Epoch: 20 [6400/20868 (31%)]
# Train Epoch: 20 [9600/20868 (46%)]
# Train Epoch: 20 [12800/20868 (61%)]
# Train Epoch: 20 [16000/20868 (77%)]
# Train Epoch: 20 [19200/20868 (92%)]
# gradient yy: 0.09923738276185552
# gradient yx: 0.038318169062154565
# Average loss: 1.1493
#
# Train Epoch: 21 [0/20868 (0%)]
# Train Epoch: 21 [3200/20868 (15%)]
# Train Epoch: 21 [6400/20868 (31%)]
# Train Epoch: 21 [9600/20868 (46%)]
# Train Epoch: 21 [12800/20868 (61%)]
# Train Epoch: 21 [16000/20868 (77%)]
# Train Epoch: 21 [19200/20868 (92%)]
# gradient yy: 0.09519507442163756
# gradient yx: 0.03747422246550375
# Average loss: 1.1485
#
# Train Epoch: 22 [0/20868 (0%)]
# Train Epoch: 22 [3200/20868 (15%)]
# Train Epoch: 22 [6400/20868 (31%)]
# Train Epoch: 22 [9600/20868 (46%)]
# Train Epoch: 22 [12800/20868 (61%)]
# Train Epoch: 22 [16000/20868 (77%)]
# Train Epoch: 22 [19200/20868 (92%)]
# gradient yy: 0.0915373973483438
# gradient yx: 0.03678960830214065
# Average loss: 1.1480
#
# Train Epoch: 23 [0/20868 (0%)]
# Train Epoch: 23 [3200/20868 (15%)]
# Train Epoch: 23 [6400/20868 (31%)]
# Train Epoch: 23 [9600/20868 (46%)]
# Train Epoch: 23 [12800/20868 (61%)]
# Train Epoch: 23 [16000/20868 (77%)]
# Train Epoch: 23 [19200/20868 (92%)]
# gradient yy: 0.08781290907352568
# gradient yx: 0.03598844740344287
# Average loss: 1.1474
#
# Train Epoch: 24 [0/20868 (0%)]
# Train Epoch: 24 [3200/20868 (15%)]
# Train Epoch: 24 [6400/20868 (31%)]
# Train Epoch: 24 [9600/20868 (46%)]
# Train Epoch: 24 [12800/20868 (61%)]
# Train Epoch: 24 [16000/20868 (77%)]
# Train Epoch: 24 [19200/20868 (92%)]
# gradient yy: 0.08461499934389745
# gradient yx: 0.03542081351275208
# Average loss: 1.1470
#
# Train Epoch: 25 [0/20868 (0%)]
# Train Epoch: 25 [3200/20868 (15%)]
# Train Epoch: 25 [6400/20868 (31%)]
# Train Epoch: 25 [9600/20868 (46%)]
# Train Epoch: 25 [12800/20868 (61%)]
# Train Epoch: 25 [16000/20868 (77%)]
# Train Epoch: 25 [19200/20868 (92%)]
# gradient yy: 0.08155241481334191
# gradient yx: 0.03489520498392713
# Average loss: 1.1467
#
#
# Testing on test set
# Average loss: 0.9867

# %%
test_data_t = torch.Tensor(np.array(list(test_data[:][0])))
test_preds = model.forward(test_data_t).detach()

# %%
np.array(list(test_data[:][0]))[:,0]
# Out:
# array([0.82096738, 0.82146362, 0.82160682, ..., 0.94956567, 0.94885924,
#        0.94813803])

# %%
test_z = np.array(list(test_data[:][0]))[:,0]
test_zdot = test_preds[:,-1]
plt.scatter(test_z, test_zdot)

# %%
direct_test_preds, direct_test_var, direct_test_loss = demo_multi.test_regression(args, model, Myy, Myx, device, test_loader, mean0, var0)

plt.scatter(test_z, direct_test_preds[:,-1])
# Out:
# Average loss: 0.9867

# %%
import seaborn as sns
sns.set(style="darkgrid")
syn_df = pd.DataFrame({
    'Fa_z(N)': direct_test_preds[:, 1],
    'z(m)': test_z
})
g = sns.scatterplot("z(m)", "Fa_z(N)", data=syn_df,
                    #xlim=(-0.2, 3.1), ylim=(-0.5, 2.2),
                    color="b",
                    #height=7,
                    #joint_kws={'alpha': 0.2}
                    alpha=0.2,
                   )

plt.ylim((-2.0, 3.2))
plt.title('Robust Regression (RMSE: 0.987)')
# Out:
# Text(0.5, 1.0, 'Robust Regression (RMSE: 0.987)')

# %%
test_y_t = torch.Tensor(list(test_data[:][1]))
np.quantile(direct_test_preds[:, -1] - test_y_t[:,2].detach().numpy(), 0.95)
# Out:
# 1.4808899615222182

# %%
test_z = np.array(list(test_data[:][:,0]))[:,0]
plt.scatter(test_z, y_pred[:, 2])
# Out:
# ------------------------------------------------------------------
# TypeError                        Traceback (most recent call last)
# <ipython-input-59-e666676e15fb> in <module>
# ----> 1 test_z = np.array(list(test_data[:][:,0]))[:,0]
#       2 plt.scatter(test_z, y_pred[:, 2])
#
# TypeError: tuple indices must be integers or slices, not tuple

# %%
test_zdot_gt = np.array(list(test_data[:][:,1]))[:,-1]
plt.scatter(test_z, test_zdot_gt)
# Out:
# ------------------------------------------------------------------
# TypeError                        Traceback (most recent call last)
# <ipython-input-60-822b966bb454> in <module>
# ----> 1 test_zdot_gt = np.array(list(test_data[:][:,1]))[:,-1]
#       2 plt.scatter(test_z, test_zdot_gt)
#
# TypeError: tuple indices must be integers or slices, not tuple

# %%
print(__doc__)

# Author: Vincent Dubourg <vincent.dubourg@gmail.com>
#         Jake Vanderplas <vanderplas@astro.washington.edu>
#         Jan Hendrik Metzen <jhm@informatik.uni-bremen.de>s
# License: BSD 3 clause

import numpy as np
from matplotlib import pyplot as plt

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C

np.random.seed(1)
# Out:
# mean0 and var0 is set according to prior knowledge and will not
# affect the result a lot in the no shift case.
# However, if there is shift and target data is far from source,
# base distribution will dominate the result.

# %%
X = inputs.copy()
x = np.zeros(X.shape)
x[:,0] = np.linspace(min(X[:,0]),max(X[:,0]), X.shape[0])
Y = dots.copy()
dY = (0.5 + 1.0 * np.random.random(Y.shape)) * 0.1
noise = np.random.normal(0, dY)
Y += noise
print(X.shape, Y.shape, x.shape, dY.shape)
# Out:
# (28983, 4) (28983, 3) (28983, 4) (28983, 3)

# %%
n = X.shape[0]
X_train = X[:int(0.8 * n)][:1000]
X_test = X[int(0.8 * n):]
Y_train = Y[:int(0.8 * n)][:1000]
Y_test = Y[int(0.8 * n):]
dy_train = dY[:int(0.8 * n)][:1000]
dy_test = dY[int(0.8 * n):]
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (1000, 4) (5797, 4) (1000, 3) (5797, 3)

# %%
# Instantiate a Gaussian Process model
kernel = RBF(0.01)
gp = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp.fit(X_train, Y_train)

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred, sigma = gp.predict(X_test, return_std=True)

# %%
np.sqrt(((Y_test - y_pred) ** 2).mean())
# Out:
# 0.5725664237118278

# %%
import seaborn as sns
sns.set(style="darkgrid")
syn_df = pd.DataFrame({
    'Fa_z(N)': y_pred[:,2],
    'z(m)': X_test[:, 0]
})
g = sns.scatterplot("z(m)", "Fa_z(N)", data=syn_df,
                    #xlim=(-0.2, 3.1), ylim=(-0.5, 2.2),
                    color="b",
                    #height=7,
                    #joint_kws={'alpha': 0.2}
                    alpha=0.8,
                   )

plt.ylim((-2.0, 3.2))
plt.title('Gaussian Process (RMSE: 0.573)')
# Out:
# Text(0.5, 1.0, 'Gaussian Process (RMSE: 0.573)')

# %%
np.quantile(y_pred[:,2] - Y_test[:,2], 0.95)
# Out:
# 1.1862990824753548

# %%
# Instantiate a Gaussian Process model
gp_0 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)
gp_1 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)
gp_2 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp_0.fit(X_train, Y_train[:,0])
gp_1.fit(X_train, Y_train[:,1])
gp_2.fit(X_train, Y_train[:,2])

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred_0, sigma = gp_0.predict(X_test, return_std=True)
y_pred_1, sigma = gp_1.predict(X_test, return_std=True)
y_pred_2, sigma = gp_2.predict(X_test, return_std=True)

# %%
np.sqrt(((Y_test - np.vstack((y_pred_0, y_pred_1, y_pred_2)).T) ** 2).mean())
# Out:
# 0.7126734515630352

# %%
inputs = df[[
    'z(m)',
    'v_x(m/s)',
    'v_y(m/s)',
    'v_z(m/s)',
    'u_1(RPM)',
    'u_2(RPM)',
    'u_3(RPM)',
    'u_4(RPM)',
]].values
dots = df[[
    'Fa_x(N)',
    'Fa_y(N)',
    'Fa_z(N)'
]].values

# %%
len(inputs)
# Out:
# 28983

# %%
# normalize control inputs
inputs[:, 4:] /= 8000.0
# randomize
index = np.random.permutation(len(inputs))
inputs = inputs[index]
dots = dots[index]
d_in = inputs.shape[1]

# %%
class Args:
    pass

use_cuda = False
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

batch_size = 32
epochs_training = 50
lr = 0.00005
momentum = 0.5
log_interval = 100
lamb = 0.001

args = Args()
args.batch_size = batch_size
args.epochs_training = epochs_training
args.lr = lr
args.momentum = momentum
args.log_interval = log_interval
split_data = SplitData(inputs, dots)

# %%
inputs[1:3]
# Out:
# array([[ 1.49407898,  0.86300911, -1.26039154,  0.08218978,  0.78353071,
#          0.87396154,  0.81938486,  0.89557972],
#        [ 0.90081807, -1.11030567,  1.21949495,  0.07179309,  0.7443712 ,
#          0.79692798,  0.8579617 ,  0.88626464]])

# %%
dots[1:3]
# Out:
# array([[ 0.62642027,  4.76875945, -0.11571027],
#        [ 0.57462796, -0.37633157,  0.27330856]])

# %%
split_data = np.random.permutation(split_data)
train_data = data.Subset(split_data, range(0, int(0.8*len(split_data))))
# 20% test set
test_data = data.Subset(split_data, range(int(0.8*len(split_data)), len(split_data)))

m_train = len(train_data)

# for covariate shift, plug in densities for source data
weight_st = np.ones(m_train)
    
weighted_train = WeightDataSet(train_data, weight_st)
m_test = len(test_data)

# for covariate shift, plug in densities for target data
weight_st = np.ones(m_test)
weighted_test = WeightDataSet(test_data, weight_st)


test_loader = data.DataLoader(weighted_test,
    batch_size=args.batch_size, shuffle=False, **kwargs)

# 10% of training as validation
m_validate = int(0.1*m_train)

validate_loader = data.DataLoader(data.Subset(weighted_train,range(0, m_validate)),
    batch_size=args.batch_size, shuffle=False, **kwargs)

# 10% validation set, note that under shift cases, cannot valiate using training data
train_loader = data.DataLoader(data.Subset(weighted_train, range(m_validate, m_train)),
    batch_size=args.batch_size, shuffle=False, **kwargs)

base_model = Net(d_in, 256, d)
base_model = base_model.to(device)

print("entering training")
model, Myy, Myx, y_pred, y_var, _  = train_validate_test(
    args, args.epochs_training, device, use_cuda, base_model, 
    train_loader, test_loader , validate_loader, lamb)
# Out:
# entering training
# Train Epoch: 1 [0/20868 (0%)]
# Train Epoch: 1 [3200/20868 (15%)]
# Train Epoch: 1 [6400/20868 (31%)]
# Train Epoch: 1 [9600/20868 (46%)]
# Train Epoch: 1 [12800/20868 (61%)]
# Train Epoch: 1 [16000/20868 (77%)]
# Train Epoch: 1 [19200/20868 (92%)]
# gradient yy: 0.8944126027685093
# gradient yx: 0.6368291893345563
# Average loss: 0.2166
#
# Train Epoch: 2 [0/20868 (0%)]
# Train Epoch: 2 [3200/20868 (15%)]
# Train Epoch: 2 [6400/20868 (31%)]
# Train Epoch: 2 [9600/20868 (46%)]
# Train Epoch: 2 [12800/20868 (61%)]
# Train Epoch: 2 [16000/20868 (77%)]
# Train Epoch: 2 [19200/20868 (92%)]
# gradient yy: 0.8766412627544102
# gradient yx: 0.3386022976527603
# Average loss: 0.2087
#
# Train Epoch: 3 [0/20868 (0%)]
# Train Epoch: 3 [3200/20868 (15%)]
# Train Epoch: 3 [6400/20868 (31%)]
# Train Epoch: 3 [9600/20868 (46%)]
# Train Epoch: 3 [12800/20868 (61%)]
# Train Epoch: 3 [16000/20868 (77%)]
# Train Epoch: 3 [19200/20868 (92%)]
# gradient yy: 0.819815241035668
# gradient yx: 0.2585611584726545
# Average loss: 0.2072
#
# Train Epoch: 4 [0/20868 (0%)]
# Train Epoch: 4 [3200/20868 (15%)]
# Train Epoch: 4 [6400/20868 (31%)]
# Train Epoch: 4 [9600/20868 (46%)]
# Train Epoch: 4 [12800/20868 (61%)]
# Train Epoch: 4 [16000/20868 (77%)]
# Train Epoch: 4 [19200/20868 (92%)]
# gradient yy: 0.7810595994580399
# gradient yx: 0.23289402222947914
# Average loss: 0.2065
#
# Train Epoch: 5 [0/20868 (0%)]
# Train Epoch: 5 [3200/20868 (15%)]
# Train Epoch: 5 [6400/20868 (31%)]
# Train Epoch: 5 [9600/20868 (46%)]
# Train Epoch: 5 [12800/20868 (61%)]
# Train Epoch: 5 [16000/20868 (77%)]
# Train Epoch: 5 [19200/20868 (92%)]
# gradient yy: 0.7532474465374934
# gradient yx: 0.21591072296157185
# Average loss: 0.2060
#
# Train Epoch: 6 [0/20868 (0%)]
# Train Epoch: 6 [3200/20868 (15%)]
# Train Epoch: 6 [6400/20868 (31%)]
# Train Epoch: 6 [9600/20868 (46%)]
# Train Epoch: 6 [12800/20868 (61%)]
# Train Epoch: 6 [16000/20868 (77%)]
# Train Epoch: 6 [19200/20868 (92%)]
# gradient yy: 0.7307746889950623
# gradient yx: 0.20150138343921256
# Average loss: 0.2055
#
# Train Epoch: 7 [0/20868 (0%)]
# Train Epoch: 7 [3200/20868 (15%)]
# Train Epoch: 7 [6400/20868 (31%)]
# Train Epoch: 7 [9600/20868 (46%)]
# Train Epoch: 7 [12800/20868 (61%)]
# Train Epoch: 7 [16000/20868 (77%)]
# Train Epoch: 7 [19200/20868 (92%)]
# gradient yy: 0.7112868428609476
# gradient yx: 0.18880782771029306
# Average loss: 0.2051
#
# Train Epoch: 8 [0/20868 (0%)]
# Train Epoch: 8 [3200/20868 (15%)]
# Train Epoch: 8 [6400/20868 (31%)]
# Train Epoch: 8 [9600/20868 (46%)]
# Train Epoch: 8 [12800/20868 (61%)]
# Train Epoch: 8 [16000/20868 (77%)]
# Train Epoch: 8 [19200/20868 (92%)]
# gradient yy: 0.6935972687715785
# gradient yx: 0.1774548036414973
# Average loss: 0.2047
#
# Train Epoch: 9 [0/20868 (0%)]
# Train Epoch: 9 [3200/20868 (15%)]
# Train Epoch: 9 [6400/20868 (31%)]
# Train Epoch: 9 [9600/20868 (46%)]
# Train Epoch: 9 [12800/20868 (61%)]
# Train Epoch: 9 [16000/20868 (77%)]
# Train Epoch: 9 [19200/20868 (92%)]
# gradient yy: 0.6775933544204547
# gradient yx: 0.16730908199074762
# Average loss: 0.2044
#
# Train Epoch: 10 [0/20868 (0%)]
# Train Epoch: 10 [3200/20868 (15%)]
# Train Epoch: 10 [6400/20868 (31%)]
# Train Epoch: 10 [9600/20868 (46%)]
# Train Epoch: 10 [12800/20868 (61%)]
# Train Epoch: 10 [16000/20868 (77%)]
# Train Epoch: 10 [19200/20868 (92%)]
# gradient yy: 0.6630638071331783
# gradient yx: 0.15822035350482408
# Average loss: 0.2040
#
# Train Epoch: 11 [0/20868 (0%)]
# Train Epoch: 11 [3200/20868 (15%)]
# Train Epoch: 11 [6400/20868 (31%)]
# Train Epoch: 11 [9600/20868 (46%)]
# Train Epoch: 11 [12800/20868 (61%)]
# Train Epoch: 11 [16000/20868 (77%)]
# Train Epoch: 11 [19200/20868 (92%)]
# gradient yy: 0.6495461736088429
# gradient yx: 0.150008884873734
# Average loss: 0.2037
#
# Train Epoch: 12 [0/20868 (0%)]
# Train Epoch: 12 [3200/20868 (15%)]
# Train Epoch: 12 [6400/20868 (31%)]
# Train Epoch: 12 [9600/20868 (46%)]
# Train Epoch: 12 [12800/20868 (61%)]
# Train Epoch: 12 [16000/20868 (77%)]
# Train Epoch: 12 [19200/20868 (92%)]
# gradient yy: 0.6369725476345509
# gradient yx: 0.14258195818221764
# Average loss: 0.2034
#
# Train Epoch: 13 [0/20868 (0%)]
# Train Epoch: 13 [3200/20868 (15%)]
# Train Epoch: 13 [6400/20868 (31%)]
# Train Epoch: 13 [9600/20868 (46%)]
# Train Epoch: 13 [12800/20868 (61%)]
# Train Epoch: 13 [16000/20868 (77%)]
# Train Epoch: 13 [19200/20868 (92%)]
# gradient yy: 0.6253390150989876
# gradient yx: 0.13586880963965628
# Average loss: 0.2031
#
# Train Epoch: 14 [0/20868 (0%)]
# Train Epoch: 14 [3200/20868 (15%)]
# Train Epoch: 14 [6400/20868 (31%)]
# Train Epoch: 14 [9600/20868 (46%)]
# Train Epoch: 14 [12800/20868 (61%)]
# Train Epoch: 14 [16000/20868 (77%)]
# Train Epoch: 14 [19200/20868 (92%)]
# gradient yy: 0.6143108662499965
# gradient yx: 0.12974664075709705
# Average loss: 0.2029
#
# Train Epoch: 15 [0/20868 (0%)]
# Train Epoch: 15 [3200/20868 (15%)]
# Train Epoch: 15 [6400/20868 (31%)]
# Train Epoch: 15 [9600/20868 (46%)]
# Train Epoch: 15 [12800/20868 (61%)]
# Train Epoch: 15 [16000/20868 (77%)]
# Train Epoch: 15 [19200/20868 (92%)]
# gradient yy: 0.6040263194633743
# gradient yx: 0.12419774093822639
# Average loss: 0.2026
#
# Train Epoch: 16 [0/20868 (0%)]
# Train Epoch: 16 [3200/20868 (15%)]
# Train Epoch: 16 [6400/20868 (31%)]
# Train Epoch: 16 [9600/20868 (46%)]
# Train Epoch: 16 [12800/20868 (61%)]
# Train Epoch: 16 [16000/20868 (77%)]
# Train Epoch: 16 [19200/20868 (92%)]
# gradient yy: 0.5944511992716041
# gradient yx: 0.11916980034855282
# Average loss: 0.2023
#
# Train Epoch: 17 [0/20868 (0%)]
# Train Epoch: 17 [3200/20868 (15%)]
# Train Epoch: 17 [6400/20868 (31%)]
# Train Epoch: 17 [9600/20868 (46%)]
# Train Epoch: 17 [12800/20868 (61%)]
# Train Epoch: 17 [16000/20868 (77%)]
# Train Epoch: 17 [19200/20868 (92%)]
# gradient yy: 0.5852445220622287
# gradient yx: 0.1145492733302156
# Average loss: 0.2020
#
# Train Epoch: 18 [0/20868 (0%)]
# Train Epoch: 18 [3200/20868 (15%)]
# Train Epoch: 18 [6400/20868 (31%)]
# Train Epoch: 18 [9600/20868 (46%)]
# Train Epoch: 18 [12800/20868 (61%)]
# Train Epoch: 18 [16000/20868 (77%)]
# Train Epoch: 18 [19200/20868 (92%)]
# gradient yy: 0.5763019197250536
# gradient yx: 0.11029386417406713
# Average loss: 0.2017
#
# Train Epoch: 19 [0/20868 (0%)]
# Train Epoch: 19 [3200/20868 (15%)]
# Train Epoch: 19 [6400/20868 (31%)]
# Train Epoch: 19 [9600/20868 (46%)]
# Train Epoch: 19 [12800/20868 (61%)]
# Train Epoch: 19 [16000/20868 (77%)]
# Train Epoch: 19 [19200/20868 (92%)]
# gradient yy: 0.5681143794185499
# gradient yx: 0.10647426755170641
# Average loss: 0.2014
#
# Train Epoch: 20 [0/20868 (0%)]
# Train Epoch: 20 [3200/20868 (15%)]
# Train Epoch: 20 [6400/20868 (31%)]
# Train Epoch: 20 [9600/20868 (46%)]
# Train Epoch: 20 [12800/20868 (61%)]
# Train Epoch: 20 [16000/20868 (77%)]
# Train Epoch: 20 [19200/20868 (92%)]
# gradient yy: 0.5600258067300171
# gradient yx: 0.102929774470107
# Average loss: 0.2011
#
# Train Epoch: 21 [0/20868 (0%)]
# Train Epoch: 21 [3200/20868 (15%)]
# Train Epoch: 21 [6400/20868 (31%)]
# Train Epoch: 21 [9600/20868 (46%)]
# Train Epoch: 21 [12800/20868 (61%)]
# Train Epoch: 21 [16000/20868 (77%)]
# Train Epoch: 21 [19200/20868 (92%)]
# gradient yy: 0.5526645421835565
# gradient yx: 0.09976596994132063
# Average loss: 0.2008
#
# Train Epoch: 22 [0/20868 (0%)]
# Train Epoch: 22 [3200/20868 (15%)]
# Train Epoch: 22 [6400/20868 (31%)]
# Train Epoch: 22 [9600/20868 (46%)]
# Train Epoch: 22 [12800/20868 (61%)]
# Train Epoch: 22 [16000/20868 (77%)]
# Train Epoch: 22 [19200/20868 (92%)]
# gradient yy: 0.5450858659543352
# gradient yx: 0.09675980922398938
# Average loss: 0.2005
#
# Train Epoch: 23 [0/20868 (0%)]
# Train Epoch: 23 [3200/20868 (15%)]
# Train Epoch: 23 [6400/20868 (31%)]
# Train Epoch: 23 [9600/20868 (46%)]
# Train Epoch: 23 [12800/20868 (61%)]
# Train Epoch: 23 [16000/20868 (77%)]
# Train Epoch: 23 [19200/20868 (92%)]
# gradient yy: 0.5380468133471447
# gradient yx: 0.09406353410167802
# Average loss: 0.2002
#
# Train Epoch: 24 [0/20868 (0%)]
# Train Epoch: 24 [3200/20868 (15%)]
# Train Epoch: 24 [6400/20868 (31%)]
# Train Epoch: 24 [9600/20868 (46%)]
# Train Epoch: 24 [12800/20868 (61%)]
# Train Epoch: 24 [16000/20868 (77%)]
# Train Epoch: 24 [19200/20868 (92%)]
# gradient yy: 0.5310871770477108
# gradient yx: 0.09155395815882965
# Average loss: 0.1998
#
# Train Epoch: 25 [0/20868 (0%)]
# Train Epoch: 25 [3200/20868 (15%)]
# Train Epoch: 25 [6400/20868 (31%)]
# Train Epoch: 25 [9600/20868 (46%)]
# Train Epoch: 25 [12800/20868 (61%)]
# Train Epoch: 25 [16000/20868 (77%)]
# Train Epoch: 25 [19200/20868 (92%)]
# gradient yy: 0.5242769139608364
# gradient yx: 0.08924608403627474
# Average loss: 0.1995
#
# Train Epoch: 26 [0/20868 (0%)]
# Train Epoch: 26 [3200/20868 (15%)]
# Train Epoch: 26 [6400/20868 (31%)]
# Train Epoch: 26 [9600/20868 (46%)]
# Train Epoch: 26 [12800/20868 (61%)]
# Train Epoch: 26 [16000/20868 (77%)]
# Train Epoch: 26 [19200/20868 (92%)]
# gradient yy: 0.5178188349953944
# gradient yx: 0.08715808977915405
# Average loss: 0.1992
#
# Train Epoch: 27 [0/20868 (0%)]
# Train Epoch: 27 [3200/20868 (15%)]
# Train Epoch: 27 [6400/20868 (31%)]
# Train Epoch: 27 [9600/20868 (46%)]
# Train Epoch: 27 [12800/20868 (61%)]
# Train Epoch: 27 [16000/20868 (77%)]
# Train Epoch: 27 [19200/20868 (92%)]
# gradient yy: 0.5111982653759275
# gradient yx: 0.0851756795579552
# Average loss: 0.1988
#
# Train Epoch: 28 [0/20868 (0%)]
# Train Epoch: 28 [3200/20868 (15%)]
# Train Epoch: 28 [6400/20868 (31%)]
# Train Epoch: 28 [9600/20868 (46%)]
# Train Epoch: 28 [12800/20868 (61%)]
# Train Epoch: 28 [16000/20868 (77%)]
# Train Epoch: 28 [19200/20868 (92%)]
# gradient yy: 0.5048530228252677
# gradient yx: 0.08337964059033573
# Average loss: 0.1985
#
# Train Epoch: 29 [0/20868 (0%)]
# Train Epoch: 29 [3200/20868 (15%)]
# Train Epoch: 29 [6400/20868 (31%)]
# Train Epoch: 29 [9600/20868 (46%)]
# Train Epoch: 29 [12800/20868 (61%)]
# Train Epoch: 29 [16000/20868 (77%)]
# Train Epoch: 29 [19200/20868 (92%)]
# gradient yy: 0.4984393293654742
# gradient yx: 0.08169834773710126
# Average loss: 0.1981
#
# Train Epoch: 30 [0/20868 (0%)]
# Train Epoch: 30 [3200/20868 (15%)]
# Train Epoch: 30 [6400/20868 (31%)]
# Train Epoch: 30 [9600/20868 (46%)]
# Train Epoch: 30 [12800/20868 (61%)]
# Train Epoch: 30 [16000/20868 (77%)]
# Train Epoch: 30 [19200/20868 (92%)]
# gradient yy: 0.49212518310060643
# gradient yx: 0.08013821254676921
# Average loss: 0.1978
#
# Train Epoch: 31 [0/20868 (0%)]
# Train Epoch: 31 [3200/20868 (15%)]
# Train Epoch: 31 [6400/20868 (31%)]
# Train Epoch: 31 [9600/20868 (46%)]
# Train Epoch: 31 [12800/20868 (61%)]
# Train Epoch: 31 [16000/20868 (77%)]
# Train Epoch: 31 [19200/20868 (92%)]
# gradient yy: 0.4857143388909917
# gradient yx: 0.07867263845695248
# Average loss: 0.1974
#
# Train Epoch: 32 [0/20868 (0%)]
# Train Epoch: 32 [3200/20868 (15%)]
# Train Epoch: 32 [6400/20868 (31%)]
# Train Epoch: 32 [9600/20868 (46%)]
# Train Epoch: 32 [12800/20868 (61%)]
# Train Epoch: 32 [16000/20868 (77%)]
# Train Epoch: 32 [19200/20868 (92%)]
# gradient yy: 0.47942023774341347
# gradient yx: 0.07731530186526438
# Average loss: 0.1970
#
# Train Epoch: 33 [0/20868 (0%)]
# Train Epoch: 33 [3200/20868 (15%)]
# Train Epoch: 33 [6400/20868 (31%)]
# Train Epoch: 33 [9600/20868 (46%)]
# Train Epoch: 33 [12800/20868 (61%)]
# Train Epoch: 33 [16000/20868 (77%)]
# Train Epoch: 33 [19200/20868 (92%)]
# gradient yy: 0.4729868357409094
# gradient yx: 0.07602488163882559
# Average loss: 0.1967
#
# Train Epoch: 34 [0/20868 (0%)]
# Train Epoch: 34 [3200/20868 (15%)]
# Train Epoch: 34 [6400/20868 (31%)]
# Train Epoch: 34 [9600/20868 (46%)]
# Train Epoch: 34 [12800/20868 (61%)]
# Train Epoch: 34 [16000/20868 (77%)]
# Train Epoch: 34 [19200/20868 (92%)]
# gradient yy: 0.4666726031797336
# gradient yx: 0.0748206151733932
# Average loss: 0.1963
#
# Train Epoch: 35 [0/20868 (0%)]
# Train Epoch: 35 [3200/20868 (15%)]
# Train Epoch: 35 [6400/20868 (31%)]
# Train Epoch: 35 [9600/20868 (46%)]
# Train Epoch: 35 [12800/20868 (61%)]
# Train Epoch: 35 [16000/20868 (77%)]
# Train Epoch: 35 [19200/20868 (92%)]
# gradient yy: 0.4604645749171955
# gradient yx: 0.07369409008549913
# Average loss: 0.1960
#
# Train Epoch: 36 [0/20868 (0%)]
# Train Epoch: 36 [3200/20868 (15%)]
# Train Epoch: 36 [6400/20868 (31%)]
# Train Epoch: 36 [9600/20868 (46%)]
# Train Epoch: 36 [12800/20868 (61%)]
# Train Epoch: 36 [16000/20868 (77%)]
# Train Epoch: 36 [19200/20868 (92%)]
# gradient yy: 0.4540682699460394
# gradient yx: 0.0726036973701649
# Average loss: 0.1957
#
# Train Epoch: 37 [0/20868 (0%)]
# Train Epoch: 37 [3200/20868 (15%)]
# Train Epoch: 37 [6400/20868 (31%)]
# Train Epoch: 37 [9600/20868 (46%)]
# Train Epoch: 37 [12800/20868 (61%)]
# Train Epoch: 37 [16000/20868 (77%)]
# Train Epoch: 37 [19200/20868 (92%)]
# gradient yy: 0.4479192933655126
# gradient yx: 0.07158569094607335
# Average loss: 0.1953
#
# Train Epoch: 38 [0/20868 (0%)]
# Train Epoch: 38 [3200/20868 (15%)]
# Train Epoch: 38 [6400/20868 (31%)]
# Train Epoch: 38 [9600/20868 (46%)]
# Train Epoch: 38 [12800/20868 (61%)]
# Train Epoch: 38 [16000/20868 (77%)]
# Train Epoch: 38 [19200/20868 (92%)]
# gradient yy: 0.44151860053489694
# gradient yx: 0.07056874600628506
# Average loss: 0.1950
#
# Train Epoch: 39 [0/20868 (0%)]
# Train Epoch: 39 [3200/20868 (15%)]
# Train Epoch: 39 [6400/20868 (31%)]
# Train Epoch: 39 [9600/20868 (46%)]
# Train Epoch: 39 [12800/20868 (61%)]
# Train Epoch: 39 [16000/20868 (77%)]
# Train Epoch: 39 [19200/20868 (92%)]
# gradient yy: 0.435062660308107
# gradient yx: 0.069598774399301
# Average loss: 0.1947
#
# Train Epoch: 40 [0/20868 (0%)]
# Train Epoch: 40 [3200/20868 (15%)]
# Train Epoch: 40 [6400/20868 (31%)]
# Train Epoch: 40 [9600/20868 (46%)]
# Train Epoch: 40 [12800/20868 (61%)]
# Train Epoch: 40 [16000/20868 (77%)]
# Train Epoch: 40 [19200/20868 (92%)]
# gradient yy: 0.4289222820632292
# gradient yx: 0.06869018670106328
# Average loss: 0.1944
#
# Train Epoch: 41 [0/20868 (0%)]
# Train Epoch: 41 [3200/20868 (15%)]
# Train Epoch: 41 [6400/20868 (31%)]
# Train Epoch: 41 [9600/20868 (46%)]
# Train Epoch: 41 [12800/20868 (61%)]
# Train Epoch: 41 [16000/20868 (77%)]
# Train Epoch: 41 [19200/20868 (92%)]
# gradient yy: 0.42270921407022116
# gradient yx: 0.06779911170559146
# Average loss: 0.1941
#
# Train Epoch: 42 [0/20868 (0%)]
# Train Epoch: 42 [3200/20868 (15%)]
# Train Epoch: 42 [6400/20868 (31%)]
# Train Epoch: 42 [9600/20868 (46%)]
# Train Epoch: 42 [12800/20868 (61%)]
# Train Epoch: 42 [16000/20868 (77%)]
# Train Epoch: 42 [19200/20868 (92%)]
# gradient yy: 0.4166976397327021
# gradient yx: 0.0669559265550882
# Average loss: 0.1938
#
# Train Epoch: 43 [0/20868 (0%)]
# Train Epoch: 43 [3200/20868 (15%)]
# Train Epoch: 43 [6400/20868 (31%)]
# Train Epoch: 43 [9600/20868 (46%)]
# Train Epoch: 43 [12800/20868 (61%)]
# Train Epoch: 43 [16000/20868 (77%)]
# Train Epoch: 43 [19200/20868 (92%)]
# gradient yy: 0.41064561235182123
# gradient yx: 0.0661285305135973
# Average loss: 0.1935
#
# Train Epoch: 44 [0/20868 (0%)]
# Train Epoch: 44 [3200/20868 (15%)]
# Train Epoch: 44 [6400/20868 (31%)]
# Train Epoch: 44 [9600/20868 (46%)]
# Train Epoch: 44 [12800/20868 (61%)]
# Train Epoch: 44 [16000/20868 (77%)]
# Train Epoch: 44 [19200/20868 (92%)]
# gradient yy: 0.40456926390392683
# gradient yx: 0.06531486119726022
# Average loss: 0.1933
#
# Train Epoch: 45 [0/20868 (0%)]
# Train Epoch: 45 [3200/20868 (15%)]
# Train Epoch: 45 [6400/20868 (31%)]
# Train Epoch: 45 [9600/20868 (46%)]
# Train Epoch: 45 [12800/20868 (61%)]
# Train Epoch: 45 [16000/20868 (77%)]
# Train Epoch: 45 [19200/20868 (92%)]
# gradient yy: 0.39895909294319165
# gradient yx: 0.06456727473436198
# Average loss: 0.1930
#
# Train Epoch: 46 [0/20868 (0%)]
# Train Epoch: 46 [3200/20868 (15%)]
# Train Epoch: 46 [6400/20868 (31%)]
# Train Epoch: 46 [9600/20868 (46%)]
# Train Epoch: 46 [12800/20868 (61%)]
# Train Epoch: 46 [16000/20868 (77%)]
# Train Epoch: 46 [19200/20868 (92%)]
# gradient yy: 0.3932428399194227
# gradient yx: 0.06382540496644645
# Average loss: 0.1928
#
# Train Epoch: 47 [0/20868 (0%)]
# Train Epoch: 47 [3200/20868 (15%)]
# Train Epoch: 47 [6400/20868 (31%)]
# Train Epoch: 47 [9600/20868 (46%)]
# Train Epoch: 47 [12800/20868 (61%)]
# Train Epoch: 47 [16000/20868 (77%)]
# Train Epoch: 47 [19200/20868 (92%)]
# gradient yy: 0.3874841301662645
# gradient yx: 0.06309694607141947
# Average loss: 0.1925
#
# Train Epoch: 48 [0/20868 (0%)]
# Train Epoch: 48 [3200/20868 (15%)]
# Train Epoch: 48 [6400/20868 (31%)]
# Train Epoch: 48 [9600/20868 (46%)]
# Train Epoch: 48 [12800/20868 (61%)]
# Train Epoch: 48 [16000/20868 (77%)]
# Train Epoch: 48 [19200/20868 (92%)]
# gradient yy: 0.3820578261293826
# gradient yx: 0.062415809315506596
# Average loss: 0.1923
#
# Train Epoch: 49 [0/20868 (0%)]
# Train Epoch: 49 [3200/20868 (15%)]
# Train Epoch: 49 [6400/20868 (31%)]
# Train Epoch: 49 [9600/20868 (46%)]
# Train Epoch: 49 [12800/20868 (61%)]
# Train Epoch: 49 [16000/20868 (77%)]
# Train Epoch: 49 [19200/20868 (92%)]
# gradient yy: 0.37649154066827695
# gradient yx: 0.06173296176438261
# Average loss: 0.1921
#
# Train Epoch: 50 [0/20868 (0%)]
# Train Epoch: 50 [3200/20868 (15%)]
# Train Epoch: 50 [6400/20868 (31%)]
# Train Epoch: 50 [9600/20868 (46%)]
# Train Epoch: 50 [12800/20868 (61%)]
# Train Epoch: 50 [16000/20868 (77%)]
# Train Epoch: 50 [19200/20868 (92%)]
# gradient yy: 0.3716518960481753
# gradient yx: 0.061131378004064735
# Average loss: 0.1919
#
#
# Testing on test set
# Average loss: 0.1893

# %%
test_data[:][:, 0].shape
# Out:
# (5797,)

# %%
test_z = np.array(list(test_data[:][:,0]))[:,0]
direct_test_preds, direct_test_var, direct_test_loss = demo_multi.test_regression(args, model, Myy, Myx, device, test_loader, mean0, var0)
plt.scatter(test_z, direct_test_preds[:,-1])
plt.xlabel('z(m)')
plt.ylabel('Fa_z(N)')
plt.title('8D, real dataset, Robust Regression, Test')
# Out:
# Average loss: 0.1893
# Text(0.5, 1.0, '8D, real dataset, Robust Regression, Test')

# %%
direct_test_preds
# Out:
# array([[ 0.25984033, -0.00317693,  0.3492853 ],
#        [ 0.25980589, -0.00319259,  0.34923593],
#        [ 0.25985628, -0.00316967,  0.34930817],
#        ...,
#        [ 0.25978586, -0.00320171,  0.34920723],
#        [ 0.25982639, -0.00318327,  0.34926532],
#        [ 0.25983928, -0.00317741,  0.34928381]])

# %%
direct_test_preds.var(axis=0)
# Out:
# array([0.0011483 , 0.00023652, 0.00235395])

# %%
X = inputs.copy()[:1000]
x = np.zeros(X.shape)
x[:,0] = np.linspace(min(X[:,0]),max(X[:,0]), X.shape[0])
Y = dots.copy()[:1000]
dY = (0.5 + 1.0 * np.random.random(Y.shape)) * 0.1
noise = np.random.normal(0, dY)
Y += noise
print(X.shape, Y.shape, x.shape, dY.shape)
# Out:
# (1000, 8) (1000, 3) (1000, 8) (1000, 3)

# %%
n = X.shape[0]
X_train = X[:int(0.8 * n)]
X_test = X[int(0.8 * n):]
Y_train = Y[:int(0.8 * n)]
Y_test = Y[int(0.8 * n):]
dy_train = dY[:int(0.8 * n)]
dy_test = dY[int(0.8 * n):]
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (800, 8) (200, 8) (800, 3) (200, 3)

# %%
# Instantiate a Gaussian Process model
kernel = RBF(0.01)
gp = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp.fit(X_train, Y_train)

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred, sigma = gp.predict(X_test, return_std=True)

# %%
np.sqrt(((Y_test - y_pred) ** 2).mean())
# Out:
# 0.662783586231257

# %%
# Instantiate a Gaussian Process model
gp_0 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)
gp_1 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)
gp_2 = GaussianProcessRegressor(kernel=kernel, alpha=dy_train[:,0] ** 2,
                              n_restarts_optimizer=10)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp_0.fit(X_train, Y_train[:,0])
gp_1.fit(X_train, Y_train[:,1])
gp_2.fit(X_train, Y_train[:,2])

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred_0, sigma = gp_0.predict(X_test, return_std=True)
y_pred_1, sigma = gp_1.predict(X_test, return_std=True)
y_pred_2, sigma = gp_2.predict(X_test, return_std=True)

# %%
np.sqrt(((Y_test - np.vstack((y_pred_0, y_pred_1, y_pred_2)).T) ** 2).mean())
# Out:
# 0.6598971316903072
